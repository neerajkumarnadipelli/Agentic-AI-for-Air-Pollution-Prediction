# %%
# Expert 4: Quantum SO2 Predictor - FIXED VARIABLE SCOPE
# Using TensorFlow SavedModel format for subclassed models

import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''  # comment out to enable GPU

import time
import json
import numpy as np
import pennylane as qml
import tensorflow as tf
from tensorflow.keras import layers, Model, optimizers, callbacks
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# ----------------------------
# CONFIG
# ----------------------------
DATA_DIR = r"C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\datasets"
OUTPUT_DIR = r"C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output"
os.makedirs(OUTPUT_DIR, exist_ok=True)

SEQ_LEN = 5
PATCH_SIZE = 10
CHANNELS = 24
PRED_BAND_IDX = 3
NUM_QUBITS = 4
Q_DEPTH = 2
EPOCHS = 100
BATCH_SIZE = 4
LR = 1e-3

np.random.seed(42)
tf.random.set_seed(42)

print("TensorFlow:", tf.__version__)
print("PennyLane:", qml.__version__)

# ----------------------------
# Load datasets
# ----------------------------

def load_npy(name):
    path = os.path.join(DATA_DIR, name)
    if not os.path.exists(path):
        raise FileNotFoundError(path)
    return np.load(path)

X_train = load_npy("X_train.npy")
y_train = load_npy("y_train.npy")
X_val = load_npy("X_val.npy")
y_val = load_npy("y_val.npy")
X_test = load_npy("X_test.npy")
y_test = load_npy("y_test.npy")

print("Loaded shapes:")
print(" X_train:", X_train.shape)
print(" y_train:", y_train.shape)
print(" X_val  :", X_val.shape)
print(" y_val  :", y_val.shape)
print(" X_test :", X_test.shape)
print(" y_test :", y_test.shape)

# Prepare SO2 targets
def extract_so2(y):
    so2 = y[..., PRED_BAND_IDX]
    return so2[..., None].astype(np.float32)

y_train_so2 = extract_so2(y_train)
y_val_so2 = extract_so2(y_val)
y_test_so2 = extract_so2(y_test)

print("SO2 target shapes:", y_train_so2.shape, y_val_so2.shape, y_test_so2.shape)

# ----------------------------
# Quantum-Enhanced Layer (Saves properly)
# ----------------------------

class QuantumEnhancedLayer(layers.Layer):
    """Custom layer that incorporates quantum-inspired operations"""
    
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        
    def build(self, input_shape):
        # Quantum-inspired weights (complex numbers represented as 2D)
        self.quantum_weights = self.add_weight(
            shape=(input_shape[-1], self.units, 2),  # Real and imaginary parts
            initializer='random_normal',
            trainable=True,
            name='quantum_weights'
        )
        self.bias = self.add_weight(
            shape=(self.units,),
            initializer='zeros',
            trainable=True,
            name='bias'
        )
        super().build(input_shape)
    
    def call(self, inputs):
        # Quantum-inspired transformation
        real_part = tf.matmul(inputs, self.quantum_weights[:, :, 0])
        imag_part = tf.matmul(inputs, self.quantum_weights[:, :, 1])
        
        # Magnitude (quantum probability amplitude inspired)
        output = tf.sqrt(real_part**2 + imag_part**2) + self.bias
        return tf.nn.relu(output)  # Non-linearity
    
    def get_config(self):
        config = super().get_config()
        config.update({"units": self.units})
        return config

def create_expert4_quantum_enhanced():
    """Expert 4 with quantum-enhanced layers (saves properly)"""
    model = tf.keras.Sequential([
        layers.InputLayer(input_shape=(SEQ_LEN, PATCH_SIZE, PATCH_SIZE, CHANNELS)),
        
        # Spatio-temporal processing
        layers.BatchNormalization(),
        layers.Conv3D(16, (3, 3, 3), activation='relu', padding='same'),
        layers.Conv3D(32, (2, 2, 2), activation='relu', padding='same'),
        layers.GlobalAveragePooling3D(),
        
        # Quantum-enhanced processing
        QuantumEnhancedLayer(64),
        layers.Dropout(0.2),
        QuantumEnhancedLayer(32),
        layers.BatchNormalization(),
        
        # Spatial reconstruction
        layers.Dense(PATCH_SIZE * PATCH_SIZE * 16, activation='relu'),
        layers.Reshape((PATCH_SIZE, PATCH_SIZE, 16)),
        
        # Final refinement
        layers.Conv2D(32, 3, activation='relu', padding='same'),
        layers.Conv2D(16, 3, activation='relu', padding='same'),
        layers.Conv2D(8, 3, activation='relu', padding='same'),
        layers.Conv2D(1, 3, activation='linear', padding='same')
    ], name="Expert4_QuantumEnhanced_SO2")
    
    return model

# ----------------------------
# Training Setup
# ----------------------------

def create_expert4_model():
    """Create Expert 4 model"""
    model = create_expert4_quantum_enhanced()
    
    optimizer = optimizers.Adam(learning_rate=LR)
    
    model.compile(
        optimizer=optimizer,
        loss='mse',
        metrics=['mae']
    )
    
    return model

def create_expert4_callbacks():
    """Create callbacks for training"""
    
    # Use TensorFlow SavedModel format
    checkpoint_cb = callbacks.ModelCheckpoint(
        os.path.join(OUTPUT_DIR, "expert4_best_model"),  # No .h5 extension
        monitor='val_loss',
        save_best_only=True,
        save_weights_only=False,
        save_format='tf',  # Use TensorFlow format
        mode='min',
        verbose=1
    )
    
    lr_scheduler = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )
    
    early_stopping = callbacks.EarlyStopping(
        monitor='val_loss',
        patience=20,
        restore_best_weights=True,
        verbose=1
    )
    
    return [checkpoint_cb, lr_scheduler, early_stopping]

# ----------------------------
# Training Execution
# ----------------------------

def train_expert4():
    """Complete training pipeline for Expert 4"""
    print("\n" + "="*60)
    print("TRAINING EXPERT 4: Quantum-Enhanced SO2 Predictor")
    print("="*60)
    
    start_time = time.time()
    
    # Create model
    print("Creating Expert 4 model...")
    expert4 = create_expert4_model()
    
    print("\nModel Architecture:")
    expert4.summary()
    
    # Create callbacks
    callbacks_list = create_expert4_callbacks()
    
    print(f"\nTraining details:")
    print(f"  Samples: {len(X_train)} training, {len(X_val)} validation")
    print(f"  Input shape: ({SEQ_LEN}, {PATCH_SIZE}, {PATCH_SIZE}, {CHANNELS})")
    print(f"  Target shape: ({PATCH_SIZE}, {PATCH_SIZE}, 1)")
    print(f"  Model type: Quantum-Enhanced Sequential")
    print(f"  Epochs: {EPOCHS}, Batch size: {BATCH_SIZE}")
    
    # Train model
    print("\nStarting training...")
    history = expert4.fit(
        X_train, y_train_so2,
        validation_data=(X_val, y_val_so2),
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        callbacks=callbacks_list,
        verbose=1,
        shuffle=True
    )
    
    training_time = time.time() - start_time
    print(f"\nTraining completed in {training_time:.2f} seconds")
    
    return expert4, history, training_time  # RETURN training_time

# ----------------------------
# Evaluation
# ----------------------------

def evaluate_expert4(model, X_test, y_test):
    """Comprehensive evaluation of Expert 4"""
    print("\n" + "="*60)
    print("EVALUATING EXPERT 4")
    print("="*60)
    
    # Predictions
    y_pred = model.predict(X_test, batch_size=BATCH_SIZE, verbose=1)
    
    # Flatten for metric calculation
    y_true_flat = y_test.reshape(-1)
    y_pred_flat = y_pred.reshape(-1)
    
    # Remove any invalid values
    mask = ~(np.isnan(y_true_flat) | np.isnan(y_pred_flat) | np.isinf(y_true_flat) | np.isinf(y_pred_flat))
    y_true_flat = y_true_flat[mask]
    y_pred_flat = y_pred_flat[mask]
    
    # Regression metrics
    mse = mean_squared_error(y_true_flat, y_pred_flat)
    mae = mean_absolute_error(y_true_flat, y_pred_flat)
    r2 = r2_score(y_true_flat, y_pred_flat)
    
    print("\n📊 PERFORMANCE METRICS:")
    print(f"  MSE:  {mse:.4f}")
    print(f"  MAE:  {mae:.4f}")
    print(f"  R²:   {r2:.4f}")
    
    # Distribution analysis
    print("\n📈 DISTRIBUTION ANALYSIS:")
    print(f"  True - Min: {y_true_flat.min():.2f}, Max: {y_true_flat.max():.2f}, Mean: {y_true_flat.mean():.2f}")
    print(f"  Pred - Min: {y_pred_flat.min():.2f}, Max: {y_pred_flat.max():.2f}, Mean: {y_pred_flat.mean():.2f}")
    
    return {
        'mse': mse,
        'mae': mae, 
        'r2': r2,
        'predictions': y_pred,
        'y_true': y_true_flat,
        'y_pred': y_pred_flat
    }

# ----------------------------
# Visualization
# ----------------------------

def plot_expert4_results(history, evaluation_results):
    """Create visualization for Expert 4"""
    
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    # Loss plot
    axes[0,0].plot(history.history['loss'], label='Training Loss')
    axes[0,0].plot(history.history['val_loss'], label='Validation Loss')
    axes[0,0].set_title('Expert 4: Training and Validation Loss')
    axes[0,0].set_xlabel('Epoch')
    axes[0,0].set_ylabel('Loss')
    axes[0,0].legend()
    axes[0,0].grid(True)
    
    # MAE plot
    axes[0,1].plot(history.history['mae'], label='Training MAE')
    axes[0,1].plot(history.history['val_mae'], label='Validation MAE')
    axes[0,1].set_title('Expert 4: Training and Validation MAE')
    axes[0,1].set_xlabel('Epoch')
    axes[0,1].set_ylabel('MAE')
    axes[0,1].legend()
    axes[0,1].grid(True)
    
    # Prediction vs True scatter
    y_true = evaluation_results['y_true']
    y_pred = evaluation_results['y_pred']
    
    axes[1,0].scatter(y_true, y_pred, alpha=0.5, s=1)
    axes[1,0].plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'r--', lw=2)
    axes[1,0].set_xlabel('True SO2')
    axes[1,0].set_ylabel('Predicted SO2')
    axes[1,0].set_title(f'Predictions vs True (R² = {evaluation_results["r2"]:.3f})')
    axes[1,0].grid(True)
    
    # Error distribution
    errors = y_pred - y_true
    axes[1,1].hist(errors, bins=50, alpha=0.7, edgecolor='black')
    axes[1,1].axvline(x=0, color='r', linestyle='--')
    axes[1,1].set_xlabel('Prediction Error')
    axes[1,1].set_ylabel('Frequency')
    axes[1,1].set_title('Prediction Error Distribution')
    axes[1,1].grid(True)
    
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, 'expert4_results.png'), dpi=300, bbox_inches='tight')
    plt.show()

# ----------------------------
# Model Saving
# ----------------------------

def save_expert4_metadata(model, history, evaluation_results, training_time):
    """Save metadata and model for Expert 4"""
    
    metadata = {
        'expert_id': 4,
        'expert_name': 'QuantumEnhanced_SO2_Predictor',
        'architecture': {
            'type': 'Quantum-Enhanced Sequential',
            'input_shape': [SEQ_LEN, PATCH_SIZE, PATCH_SIZE, CHANNELS],
            'output_shape': [PATCH_SIZE, PATCH_SIZE, 1],
            'quantum_inspired': True
        },
        'training': {
            'epochs_trained': len(history.history['loss']),
            'final_train_loss': float(history.history['loss'][-1]),
            'final_val_loss': float(history.history['val_loss'][-1]),
            'training_time_seconds': float(training_time),
            'batch_size': BATCH_SIZE,
            'learning_rate': LR
        },
        'performance': {
            'test_mse': float(evaluation_results['mse']),
            'test_mae': float(evaluation_results['mae']),
            'test_r2': float(evaluation_results['r2'])
        },
        'target_band': 'SO2',
        'saved_format': 'TensorFlow SavedModel',
        'timestamp': time.strftime('%Y-%m-%d %H:%M:%S')
    }
    
    # Save metadata
    with open(os.path.join(OUTPUT_DIR, 'expert4_metadata.json'), 'w') as f:
        json.dump(metadata, f, indent=2)
    
    # Save final model in TensorFlow format
    model.save(os.path.join(OUTPUT_DIR, 'expert4_final_model'), save_format='tf')
    
    # Also save weights for compatibility
    model.save_weights(os.path.join(OUTPUT_DIR, 'expert4_weights.h5'))
    
    print(f"\n💾 Expert 4 saved successfully!")
    print(f"   Model: {OUTPUT_DIR}/expert4_final_model/ (TensorFlow format)")
    print(f"   Weights: {OUTPUT_DIR}/expert4_weights.h5")
    print(f"   Metadata: {OUTPUT_DIR}/expert4_metadata.json")

# ----------------------------
# Model Loading Function
# ----------------------------

def load_expert4_model():
    """Load trained Expert 4 model"""
    model_path = os.path.join(OUTPUT_DIR, 'expert4_final_model')
    if os.path.exists(model_path):
        return tf.keras.models.load_model(model_path, custom_objects={'QuantumEnhancedLayer': QuantumEnhancedLayer})
    else:
        print("Model not found. Please train first.")
        return None

# ----------------------------
# Main Execution
# ----------------------------

if __name__ == "__main__":
    print("🚀 STARTING EXPERT 4: Quantum-Enhanced SO2 Predictor")
    
    try:
        # Step 1: Train Expert 4
        expert4_model, training_history, training_time = train_expert4()  # CAPTURE training_time
        
        # Step 2: Evaluate Expert 4
        evaluation_results = evaluate_expert4(expert4_model, X_test, y_test_so2)
        
        # Step 3: Visualize results
        plot_expert4_results(training_history, evaluation_results)
        
        # Step 4: Save model and metadata
        save_expert4_metadata(expert4_model, training_history, evaluation_results, training_time)
        
        print("\n✅ EXPERT 4 COMPLETED SUCCESSFULLY!")
        print("📁 Model ready for ensemble stacking!")
        
        # Test loading the model
        print("\n🧪 Testing model loading...")
        loaded_model = load_expert4_model()
        if loaded_model:
            print("✅ Model loaded successfully for ensemble integration!")
            
    except Exception as e:
        print(f"\n❌ ERROR in Expert 4: {e}")
        import traceback
        traceback.print_exc()
# Out:
# TensorFlow: 2.10.1
# PennyLane: 0.32.0
# Loaded shapes:
#  X_train: (994, 5, 10, 10, 24)
#  y_train: (994, 10, 10, 7)
#  X_val  : (213, 5, 10, 10, 24)
#  y_val  : (213, 10, 10, 7)
#  X_test : (214, 5, 10, 10, 24)
#  y_test : (214, 10, 10, 7)
# SO2 target shapes: (994, 10, 10, 1) (213, 10, 10, 1) (214, 10, 10, 1)
# 🚀 STARTING EXPERT 4: Quantum-Enhanced SO2 Predictor
#
# ============================================================
# TRAINING EXPERT 4: Quantum-Enhanced SO2 Predictor
# ============================================================
# Creating Expert 4 model...
#
# Model Architecture:
# Model: "Expert4_QuantumEnhanced_SO2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_2 (Batc  (None, 5, 10, 10, 24)    96
#  hNormalization)
#
#  conv3d_2 (Conv3D)           (None, 5, 10, 10, 16)     10384
#
#  conv3d_3 (Conv3D)           (None, 5, 10, 10, 32)     4128
#
#  global_average_pooling3d_1   (None, 32)               0
#  (GlobalAveragePooling3D)
#
#  quantum_enhanced_layer_2 (Q  (None, 64)               4160
#  uantumEnhancedLayer)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  quantum_enhanced_layer_3 (Q  (None, 32)               4128
#  uantumEnhancedLayer)
#
#  batch_normalization_3 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_1 (Dense)             (None, 1600)              52800
#
#  reshape_1 (Reshape)         (None, 10, 10, 16)        0
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 32)        4640
#
#  conv2d_5 (Conv2D)           (None, 10, 10, 16)        4624
#
#  conv2d_6 (Conv2D)           (None, 10, 10, 8)         1160
#
#  conv2d_7 (Conv2D)           (None, 10, 10, 1)         73
#
# =================================================================
# Total params: 86,321
# Trainable params: 86,209
# Non-trainable params: 112
# _________________________________________________________________
#
# Training details:
#   Samples: 994 training, 213 validation
#   Input shape: (5, 10, 10, 24)
#   Target shape: (10, 10, 1)
#   Model type: Quantum-Enhanced Sequential
#   Epochs: 100, Batch size: 4
#
# Starting training...
# Epoch 1/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0295 - mae: 0.1144
# Epoch 1: val_loss improved from inf to 0.03514, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# 249/249 [==============================] - 17s 57ms/step - loss: 0.0295 - mae: 0.1145 - val_loss: 0.0351 - val_mae: 0.1237 - lr: 0.0010
# Epoch 2/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0208 - mae: 0.1010
# Epoch 2: val_loss improved from 0.03514 to 0.01388, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# 249/249 [==============================] - 12s 47ms/step - loss: 0.0208 - mae: 0.1009 - val_loss: 0.0139 - val_mae: 0.0941 - lr: 0.0010
# Epoch 3/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0144 - mae: 0.0905
# Epoch 3: val_loss improved from 0.01388 to 0.01346, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# 249/249 [==============================] - 11s 45ms/step - loss: 0.0144 - mae: 0.0904 - val_loss: 0.0135 - val_mae: 0.0982 - lr: 0.0010
# Epoch 4/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0137 - mae: 0.0906
# Epoch 4: val_loss improved from 0.01346 to 0.01050, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# 249/249 [==============================] - 14s 56ms/step - loss: 0.0137 - mae: 0.0906 - val_loss: 0.0105 - val_mae: 0.0876 - lr: 0.0010
# Epoch 5/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0106 - mae: 0.0815
# Epoch 5: val_loss did not improve from 0.01050
# 249/249 [==============================] - 9s 35ms/step - loss: 0.0105 - mae: 0.0815 - val_loss: 0.0122 - val_mae: 0.0877 - lr: 0.0010
# Epoch 6/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0080 - mae: 0.0715
# Epoch 6: val_loss improved from 0.01050 to 0.00959, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# 249/249 [==============================] - 14s 56ms/step - loss: 0.0080 - mae: 0.0717 - val_loss: 0.0096 - val_mae: 0.0780 - lr: 0.0010
# Epoch 7/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0112 - mae: 0.0765
# Epoch 7: val_loss did not improve from 0.00959
# 249/249 [==============================] - 4s 17ms/step - loss: 0.0112 - mae: 0.0766 - val_loss: 0.0103 - val_mae: 0.0736 - lr: 0.0010
# Epoch 8/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0090 - mae: 0.0723
# Epoch 8: val_loss did not improve from 0.00959
# 249/249 [==============================] - 4s 17ms/step - loss: 0.0090 - mae: 0.0723 - val_loss: 0.0104 - val_mae: 0.0651 - lr: 0.0010
# Epoch 9/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0086 - mae: 0.0689
# Epoch 9: val_loss did not improve from 0.00959
# 249/249 [==============================] - 5s 19ms/step - loss: 0.0086 - mae: 0.0689 - val_loss: 0.0108 - val_mae: 0.0697 - lr: 0.0010
# Epoch 10/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0084 - mae: 0.0668
# Epoch 10: val_loss did not improve from 0.00959
# 249/249 [==============================] - 5s 19ms/step - loss: 0.0084 - mae: 0.0668 - val_loss: 0.0102 - val_mae: 0.0806 - lr: 0.0010
# Epoch 11/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0067 - mae: 0.0610
# Epoch 11: val_loss did not improve from 0.00959
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 249/249 [==============================] - 20s 79ms/step - loss: 0.0067 - mae: 0.0610 - val_loss: 0.0113 - val_mae: 0.0582 - lr: 0.0010
# Epoch 12/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0041 - mae: 0.0501
# Epoch 12: val_loss did not improve from 0.00959
# 249/249 [==============================] - 27s 107ms/step - loss: 0.0041 - mae: 0.0502 - val_loss: 0.0135 - val_mae: 0.0597 - lr: 5.0000e-04
# Epoch 13/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0037 - mae: 0.0471
# Epoch 13: val_loss improved from 0.00959 to 0.00877, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# 249/249 [==============================] - 32s 129ms/step - loss: 0.0037 - mae: 0.0471 - val_loss: 0.0088 - val_mae: 0.0500 - lr: 5.0000e-04
# Epoch 14/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0036 - mae: 0.0456
# Epoch 14: val_loss improved from 0.00877 to 0.00682, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# 249/249 [==============================] - 43s 172ms/step - loss: 0.0036 - mae: 0.0456 - val_loss: 0.0068 - val_mae: 0.0454 - lr: 5.0000e-04
# Epoch 15/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0033 - mae: 0.0435
# Epoch 15: val_loss did not improve from 0.00682
# 249/249 [==============================] - 29s 117ms/step - loss: 0.0033 - mae: 0.0435 - val_loss: 0.0109 - val_mae: 0.0555 - lr: 5.0000e-04
# Epoch 16/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0028 - mae: 0.0407
# Epoch 16: val_loss did not improve from 0.00682
# 249/249 [==============================] - 24s 98ms/step - loss: 0.0028 - mae: 0.0407 - val_loss: 0.0069 - val_mae: 0.0487 - lr: 5.0000e-04
# Epoch 17/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0031 - mae: 0.0407
# Epoch 17: val_loss did not improve from 0.00682
# 249/249 [==============================] - 10s 39ms/step - loss: 0.0031 - mae: 0.0407 - val_loss: 0.0080 - val_mae: 0.0519 - lr: 5.0000e-04
# Epoch 18/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0435
# Epoch 18: val_loss did not improve from 0.00682
# 249/249 [==============================] - 5s 20ms/step - loss: 0.0033 - mae: 0.0434 - val_loss: 0.0091 - val_mae: 0.0507 - lr: 5.0000e-04
# Epoch 19/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0025 - mae: 0.0389
# Epoch 19: val_loss improved from 0.00682 to 0.00666, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# 249/249 [==============================] - 44s 177ms/step - loss: 0.0025 - mae: 0.0389 - val_loss: 0.0067 - val_mae: 0.0513 - lr: 5.0000e-04
# Epoch 20/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0026 - mae: 0.0375
# Epoch 20: val_loss did not improve from 0.00666
# 249/249 [==============================] - 26s 104ms/step - loss: 0.0026 - mae: 0.0375 - val_loss: 0.0073 - val_mae: 0.0485 - lr: 5.0000e-04
# Epoch 21/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0026 - mae: 0.0380
# Epoch 21: val_loss did not improve from 0.00666
# 249/249 [==============================] - 26s 105ms/step - loss: 0.0026 - mae: 0.0380 - val_loss: 0.0082 - val_mae: 0.0501 - lr: 5.0000e-04
# Epoch 22/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0028 - mae: 0.0379
# Epoch 22: val_loss improved from 0.00666 to 0.00499, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# 249/249 [==============================] - 32s 129ms/step - loss: 0.0028 - mae: 0.0379 - val_loss: 0.0050 - val_mae: 0.0456 - lr: 5.0000e-04
# Epoch 23/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0408
# Epoch 23: val_loss did not improve from 0.00499
# 249/249 [==============================] - 14s 57ms/step - loss: 0.0034 - mae: 0.0408 - val_loss: 0.0118 - val_mae: 0.0535 - lr: 5.0000e-04
# Epoch 24/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0023 - mae: 0.0354
# Epoch 24: val_loss improved from 0.00499 to 0.00353, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# 249/249 [==============================] - 20s 80ms/step - loss: 0.0023 - mae: 0.0354 - val_loss: 0.0035 - val_mae: 0.0346 - lr: 5.0000e-04
# Epoch 25/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0027 - mae: 0.0368
# Epoch 25: val_loss did not improve from 0.00353
# 249/249 [==============================] - 10s 40ms/step - loss: 0.0027 - mae: 0.0368 - val_loss: 0.0045 - val_mae: 0.0393 - lr: 5.0000e-04
# Epoch 26/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0324
# Epoch 26: val_loss did not improve from 0.00353
# 249/249 [==============================] - 9s 38ms/step - loss: 0.0018 - mae: 0.0324 - val_loss: 0.0039 - val_mae: 0.0378 - lr: 5.0000e-04
# Epoch 27/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0025 - mae: 0.0337
# Epoch 27: val_loss did not improve from 0.00353
# 249/249 [==============================] - 9s 38ms/step - loss: 0.0025 - mae: 0.0338 - val_loss: 0.0058 - val_mae: 0.0376 - lr: 5.0000e-04
# Epoch 28/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0020 - mae: 0.0321
# Epoch 28: val_loss did not improve from 0.00353
# 249/249 [==============================] - 10s 39ms/step - loss: 0.0020 - mae: 0.0321 - val_loss: 0.0059 - val_mae: 0.0391 - lr: 5.0000e-04
# Epoch 29/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0021 - mae: 0.0326
# Epoch 29: val_loss did not improve from 0.00353
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 249/249 [==============================] - 8s 31ms/step - loss: 0.0021 - mae: 0.0326 - val_loss: 0.0188 - val_mae: 0.0567 - lr: 5.0000e-04
# Epoch 30/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0018 - mae: 0.0290
# Epoch 30: val_loss did not improve from 0.00353
# 249/249 [==============================] - 10s 42ms/step - loss: 0.0018 - mae: 0.0290 - val_loss: 0.0041 - val_mae: 0.0341 - lr: 2.5000e-04
# Epoch 31/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0016 - mae: 0.0284
# Epoch 31: val_loss did not improve from 0.00353
# 249/249 [==============================] - 10s 39ms/step - loss: 0.0016 - mae: 0.0283 - val_loss: 0.0061 - val_mae: 0.0371 - lr: 2.5000e-04
# Epoch 32/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0272
# Epoch 32: val_loss did not improve from 0.00353
# 249/249 [==============================] - 9s 37ms/step - loss: 0.0013 - mae: 0.0272 - val_loss: 0.0038 - val_mae: 0.0333 - lr: 2.5000e-04
# Epoch 33/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0015 - mae: 0.0276
# Epoch 33: val_loss did not improve from 0.00353
# 249/249 [==============================] - 12s 47ms/step - loss: 0.0015 - mae: 0.0276 - val_loss: 0.0048 - val_mae: 0.0322 - lr: 2.5000e-04
# Epoch 34/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0260
# Epoch 34: val_loss did not improve from 0.00353
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 249/249 [==============================] - 20s 79ms/step - loss: 0.0013 - mae: 0.0260 - val_loss: 0.0039 - val_mae: 0.0312 - lr: 2.5000e-04
# Epoch 35/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0255
# Epoch 35: val_loss did not improve from 0.00353
# 249/249 [==============================] - 14s 54ms/step - loss: 0.0013 - mae: 0.0256 - val_loss: 0.0044 - val_mae: 0.0339 - lr: 1.2500e-04
# Epoch 36/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0015 - mae: 0.0264
# Epoch 36: val_loss did not improve from 0.00353
# 249/249 [==============================] - 12s 48ms/step - loss: 0.0015 - mae: 0.0264 - val_loss: 0.0040 - val_mae: 0.0319 - lr: 1.2500e-04
# Epoch 37/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0252
# Epoch 37: val_loss did not improve from 0.00353
# 249/249 [==============================] - 23s 93ms/step - loss: 0.0014 - mae: 0.0253 - val_loss: 0.0038 - val_mae: 0.0300 - lr: 1.2500e-04
# Epoch 38/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0246
# Epoch 38: val_loss did not improve from 0.00353
# 249/249 [==============================] - 8s 33ms/step - loss: 0.0012 - mae: 0.0246 - val_loss: 0.0060 - val_mae: 0.0340 - lr: 1.2500e-04
# Epoch 39/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0015 - mae: 0.0264
# Epoch 39: val_loss did not improve from 0.00353
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 249/249 [==============================] - 25s 102ms/step - loss: 0.0015 - mae: 0.0264 - val_loss: 0.0047 - val_mae: 0.0308 - lr: 1.2500e-04
# Epoch 40/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0249
# Epoch 40: val_loss improved from 0.00353 to 0.00323, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# 249/249 [==============================] - 45s 182ms/step - loss: 0.0013 - mae: 0.0249 - val_loss: 0.0032 - val_mae: 0.0285 - lr: 6.2500e-05
# Epoch 41/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0012 - mae: 0.0238
# Epoch 41: val_loss improved from 0.00323 to 0.00319, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# 249/249 [==============================] - 24s 96ms/step - loss: 0.0012 - mae: 0.0238 - val_loss: 0.0032 - val_mae: 0.0286 - lr: 6.2500e-05
# Epoch 42/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0011 - mae: 0.0245
# Epoch 42: val_loss did not improve from 0.00319
# 249/249 [==============================] - 21s 84ms/step - loss: 0.0011 - mae: 0.0245 - val_loss: 0.0034 - val_mae: 0.0293 - lr: 6.2500e-05
# Epoch 43/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0243
# Epoch 43: val_loss did not improve from 0.00319
# 249/249 [==============================] - 26s 105ms/step - loss: 0.0012 - mae: 0.0243 - val_loss: 0.0041 - val_mae: 0.0298 - lr: 6.2500e-05
# Epoch 44/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0010 - mae: 0.0233
# Epoch 44: val_loss did not improve from 0.00319
# 249/249 [==============================] - 13s 52ms/step - loss: 0.0010 - mae: 0.0233 - val_loss: 0.0033 - val_mae: 0.0291 - lr: 6.2500e-05
# Epoch 45/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0025 - mae: 0.0256
# Epoch 45: val_loss did not improve from 0.00319
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 249/249 [==============================] - 15s 60ms/step - loss: 0.0025 - mae: 0.0256 - val_loss: 0.0037 - val_mae: 0.0291 - lr: 6.2500e-05
# Epoch 46/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0011 - mae: 0.0234
# Epoch 46: val_loss did not improve from 0.00319
# 249/249 [==============================] - 23s 94ms/step - loss: 0.0011 - mae: 0.0235 - val_loss: 0.0034 - val_mae: 0.0283 - lr: 3.1250e-05
# Epoch 47/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0240
# Epoch 47: val_loss did not improve from 0.00319
# 249/249 [==============================] - 20s 82ms/step - loss: 0.0014 - mae: 0.0242 - val_loss: 0.0034 - val_mae: 0.0287 - lr: 3.1250e-05
# Epoch 48/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0244
# Epoch 48: val_loss did not improve from 0.00319
# 249/249 [==============================] - 9s 34ms/step - loss: 0.0012 - mae: 0.0243 - val_loss: 0.0039 - val_mae: 0.0294 - lr: 3.1250e-05
# Epoch 49/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0244
# Epoch 49: val_loss did not improve from 0.00319
# 249/249 [==============================] - 23s 92ms/step - loss: 0.0013 - mae: 0.0244 - val_loss: 0.0038 - val_mae: 0.0295 - lr: 3.1250e-05
# Epoch 50/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0238
# Epoch 50: val_loss improved from 0.00319 to 0.00302, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# 249/249 [==============================] - 33s 134ms/step - loss: 0.0013 - mae: 0.0238 - val_loss: 0.0030 - val_mae: 0.0271 - lr: 3.1250e-05
# Epoch 51/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0011 - mae: 0.0222
# Epoch 51: val_loss did not improve from 0.00302
# 249/249 [==============================] - 19s 77ms/step - loss: 0.0011 - mae: 0.0222 - val_loss: 0.0035 - val_mae: 0.0290 - lr: 3.1250e-05
# Epoch 52/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0011 - mae: 0.0232
# Epoch 52: val_loss did not improve from 0.00302
# 249/249 [==============================] - 8s 32ms/step - loss: 0.0011 - mae: 0.0232 - val_loss: 0.0038 - val_mae: 0.0291 - lr: 3.1250e-05
# Epoch 53/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0011 - mae: 0.0234
# Epoch 53: val_loss did not improve from 0.00302
# 249/249 [==============================] - 23s 94ms/step - loss: 0.0011 - mae: 0.0235 - val_loss: 0.0032 - val_mae: 0.0277 - lr: 3.1250e-05
# Epoch 54/100
# 249/249 [==============================] - ETA: 0s - loss: 9.9652e-04 - mae: 0.0224
# Epoch 54: val_loss improved from 0.00302 to 0.00274, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# 249/249 [==============================] - 33s 135ms/step - loss: 9.9652e-04 - mae: 0.0224 - val_loss: 0.0027 - val_mae: 0.0265 - lr: 3.1250e-05
# Epoch 55/100
# 248/249 [============================>.] - ETA: 0s - loss: 8.9817e-04 - mae: 0.0218
# Epoch 55: val_loss improved from 0.00274 to 0.00267, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# 249/249 [==============================] - 32s 127ms/step - loss: 8.9693e-04 - mae: 0.0218 - val_loss: 0.0027 - val_mae: 0.0266 - lr: 3.1250e-05
# Epoch 56/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0011 - mae: 0.0233
# Epoch 56: val_loss did not improve from 0.00267
# 249/249 [==============================] - 15s 61ms/step - loss: 0.0011 - mae: 0.0233 - val_loss: 0.0027 - val_mae: 0.0265 - lr: 3.1250e-05
# Epoch 57/100
# 249/249 [==============================] - ETA: 0s - loss: 8.2382e-04 - mae: 0.0216
# Epoch 57: val_loss improved from 0.00267 to 0.00267, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_best_model\assets
# 249/249 [==============================] - 22s 88ms/step - loss: 8.2382e-04 - mae: 0.0216 - val_loss: 0.0027 - val_mae: 0.0264 - lr: 3.1250e-05
# Epoch 58/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0011 - mae: 0.0236
# Epoch 58: val_loss did not improve from 0.00267
# 249/249 [==============================] - 23s 94ms/step - loss: 0.0011 - mae: 0.0236 - val_loss: 0.0037 - val_mae: 0.0296 - lr: 3.1250e-05
# Epoch 59/100
# 248/249 [============================>.] - ETA: 0s - loss: 9.2554e-04 - mae: 0.0226
# Epoch 59: val_loss did not improve from 0.00267
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 249/249 [==============================] - 25s 100ms/step - loss: 9.2587e-04 - mae: 0.0226 - val_loss: 0.0041 - val_mae: 0.0313 - lr: 3.1250e-05
# Epoch 60/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0010 - mae: 0.0218
# Epoch 60: val_loss did not improve from 0.00267
# 249/249 [==============================] - 25s 99ms/step - loss: 0.0010 - mae: 0.0218 - val_loss: 0.0035 - val_mae: 0.0287 - lr: 1.5625e-05
# Epoch 61/100
# 249/249 [==============================] - ETA: 0s - loss: 8.0824e-04 - mae: 0.0208
# Epoch 61: val_loss did not improve from 0.00267
# 249/249 [==============================] - 23s 94ms/step - loss: 8.0824e-04 - mae: 0.0208 - val_loss: 0.0031 - val_mae: 0.0277 - lr: 1.5625e-05
# Epoch 62/100
# 247/249 [============================>.] - ETA: 0s - loss: 8.9825e-04 - mae: 0.0221
# Epoch 62: val_loss did not improve from 0.00267
# 249/249 [==============================] - 22s 87ms/step - loss: 8.9740e-04 - mae: 0.0221 - val_loss: 0.0036 - val_mae: 0.0288 - lr: 1.5625e-05
# Epoch 63/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0012 - mae: 0.0225
# Epoch 63: val_loss did not improve from 0.00267
# 249/249 [==============================] - 22s 89ms/step - loss: 0.0012 - mae: 0.0225 - val_loss: 0.0030 - val_mae: 0.0275 - lr: 1.5625e-05
# Epoch 64/100
# 248/249 [============================>.] - ETA: 0s - loss: 7.9427e-04 - mae: 0.0210
# Epoch 64: val_loss did not improve from 0.00267
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 249/249 [==============================] - 8s 33ms/step - loss: 7.9314e-04 - mae: 0.0210 - val_loss: 0.0029 - val_mae: 0.0264 - lr: 1.5625e-05
# Epoch 65/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0235
# Epoch 65: val_loss did not improve from 0.00267
# 249/249 [==============================] - 18s 72ms/step - loss: 0.0013 - mae: 0.0235 - val_loss: 0.0035 - val_mae: 0.0282 - lr: 7.8125e-06
# Epoch 66/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0011 - mae: 0.0230
# Epoch 66: val_loss did not improve from 0.00267
# 249/249 [==============================] - 24s 97ms/step - loss: 0.0011 - mae: 0.0230 - val_loss: 0.0035 - val_mae: 0.0285 - lr: 7.8125e-06
# Epoch 67/100
# 249/249 [==============================] - ETA: 0s - loss: 9.3129e-04 - mae: 0.0218
# Epoch 67: val_loss did not improve from 0.00267
# 249/249 [==============================] - 25s 100ms/step - loss: 9.3129e-04 - mae: 0.0218 - val_loss: 0.0031 - val_mae: 0.0276 - lr: 7.8125e-06
# Epoch 68/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0228
# Epoch 68: val_loss did not improve from 0.00267
# 249/249 [==============================] - 24s 95ms/step - loss: 0.0012 - mae: 0.0228 - val_loss: 0.0032 - val_mae: 0.0274 - lr: 7.8125e-06
# Epoch 69/100
# 248/249 [============================>.] - ETA: 0s - loss: 8.4430e-04 - mae: 0.0216
# Epoch 69: val_loss did not improve from 0.00267
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 249/249 [==============================] - 23s 94ms/step - loss: 8.4479e-04 - mae: 0.0216 - val_loss: 0.0032 - val_mae: 0.0277 - lr: 7.8125e-06
# Epoch 70/100
# 249/249 [==============================] - ETA: 0s - loss: 8.1344e-04 - mae: 0.0215
# Epoch 70: val_loss did not improve from 0.00267
# 249/249 [==============================] - 26s 104ms/step - loss: 8.1344e-04 - mae: 0.0215 - val_loss: 0.0029 - val_mae: 0.0267 - lr: 3.9063e-06
# Epoch 71/100
# 247/249 [============================>.] - ETA: 0s - loss: 9.5421e-04 - mae: 0.0223
# Epoch 71: val_loss did not improve from 0.00267
# 249/249 [==============================] - 10s 41ms/step - loss: 9.5615e-04 - mae: 0.0223 - val_loss: 0.0031 - val_mae: 0.0274 - lr: 3.9063e-06
# Epoch 72/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0239
# Epoch 72: val_loss did not improve from 0.00267
# 249/249 [==============================] - 18s 74ms/step - loss: 0.0013 - mae: 0.0239 - val_loss: 0.0033 - val_mae: 0.0276 - lr: 3.9063e-06
# Epoch 73/100
# 248/249 [============================>.] - ETA: 0s - loss: 9.9549e-04 - mae: 0.0225
# Epoch 73: val_loss did not improve from 0.00267
# 249/249 [==============================] - 25s 100ms/step - loss: 9.9912e-04 - mae: 0.0225 - val_loss: 0.0033 - val_mae: 0.0279 - lr: 3.9063e-06
# Epoch 74/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0011 - mae: 0.0220
# Epoch 74: val_loss did not improve from 0.00267
#
# Epoch 74: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 249/249 [==============================] - 24s 95ms/step - loss: 0.0011 - mae: 0.0220 - val_loss: 0.0032 - val_mae: 0.0273 - lr: 3.9063e-06
# Epoch 75/100
# 249/249 [==============================] - ETA: 0s - loss: 9.2973e-04 - mae: 0.0218
# Epoch 75: val_loss did not improve from 0.00267
# 249/249 [==============================] - 23s 94ms/step - loss: 9.2973e-04 - mae: 0.0218 - val_loss: 0.0032 - val_mae: 0.0273 - lr: 1.9531e-06
# Epoch 76/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0233
# Epoch 76: val_loss did not improve from 0.00267
# 249/249 [==============================] - 23s 94ms/step - loss: 0.0012 - mae: 0.0236 - val_loss: 0.0031 - val_mae: 0.0271 - lr: 1.9531e-06
# Epoch 77/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0235
# Epoch 77: val_loss did not improve from 0.00267
# Restoring model weights from the end of the best epoch: 57.
# 249/249 [==============================] - 24s 94ms/step - loss: 0.0014 - mae: 0.0235 - val_loss: 0.0033 - val_mae: 0.0279 - lr: 1.9531e-06
# Epoch 77: early stopping
#
# Training completed in 1477.90 seconds
#
# ============================================================
# EVALUATING EXPERT 4
# ============================================================
# 54/54 [==============================] - 3s 32ms/step
#
# 📊 PERFORMANCE METRICS:
#   MSE:  0.0021
#   MAE:  0.0234
#   R²:   0.9307
#
# 📈 DISTRIBUTION ANALYSIS:
#   True - Min: 0.00, Max: 1.00, Mean: 0.20
#   Pred - Min: -0.04, Max: 1.24, Mean: 0.21
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_final_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output\expert4_final_model\assets
# 💾 Expert 4 saved successfully!
#    Model: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output/expert4_final_model/ (TensorFlow format)
#    Weights: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output/expert4_weights.h5
#    Metadata: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert4_output/expert4_metadata.json
#
# ✅ EXPERT 4 COMPLETED SUCCESSFULLY!
# 📁 Model ready for ensemble stacking!
#
# 🧪 Testing model loading...
# ✅ Model loaded successfully for ensemble integration!
