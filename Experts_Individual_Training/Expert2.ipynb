# %%
# Expert 2: Quantum PM10 Predictor - FIXED VARIABLE SCOPE
# Using TensorFlow SavedModel format for subclassed models

import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''  # comment out to enable GPU

import time
import json
import numpy as np
import pennylane as qml
import tensorflow as tf
from tensorflow.keras import layers, Model, optimizers, callbacks
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# ----------------------------
# CONFIG
# ----------------------------
DATA_DIR = r"C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\datasets"
OUTPUT_DIR = r"C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output"
os.makedirs(OUTPUT_DIR, exist_ok=True)

SEQ_LEN = 5
PATCH_SIZE = 10
CHANNELS = 24
PRED_BAND_IDX = 1
NUM_QUBITS = 4
Q_DEPTH = 2
EPOCHS = 100
BATCH_SIZE = 4
LR = 1e-3

np.random.seed(42)
tf.random.set_seed(42)

print("TensorFlow:", tf.__version__)
print("PennyLane:", qml.__version__)

# ----------------------------
# Load datasets
# ----------------------------

def load_npy(name):
    path = os.path.join(DATA_DIR, name)
    if not os.path.exists(path):
        raise FileNotFoundError(path)
    return np.load(path)

X_train = load_npy("X_train.npy")
y_train = load_npy("y_train.npy")
X_val = load_npy("X_val.npy")
y_val = load_npy("y_val.npy")
X_test = load_npy("X_test.npy")
y_test = load_npy("y_test.npy")

print("Loaded shapes:")
print(" X_train:", X_train.shape)
print(" y_train:", y_train.shape)
print(" X_val  :", X_val.shape)
print(" y_val  :", y_val.shape)
print(" X_test :", X_test.shape)
print(" y_test :", y_test.shape)

# Prepare PM10 targets
def extract_pm10(y):
    pm10 = y[..., PRED_BAND_IDX]
    return pm10[..., None].astype(np.float32)

y_train_pm10 = extract_pm10(y_train)
y_val_pm10 = extract_pm10(y_val)
y_test_pm10 = extract_pm10(y_test)

print("PM10 target shapes:", y_train_pm10.shape, y_val_pm10.shape, y_test_pm10.shape)

# ----------------------------
# Quantum-Enhanced Layer (Saves properly)
# ----------------------------

class QuantumEnhancedLayer(layers.Layer):
    """Custom layer that incorporates quantum-inspired operations"""
    
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        
    def build(self, input_shape):
        # Quantum-inspired weights (complex numbers represented as 2D)
        self.quantum_weights = self.add_weight(
            shape=(input_shape[-1], self.units, 2),  # Real and imaginary parts
            initializer='random_normal',
            trainable=True,
            name='quantum_weights'
        )
        self.bias = self.add_weight(
            shape=(self.units,),
            initializer='zeros',
            trainable=True,
            name='bias'
        )
        super().build(input_shape)
    
    def call(self, inputs):
        # Quantum-inspired transformation
        real_part = tf.matmul(inputs, self.quantum_weights[:, :, 0])
        imag_part = tf.matmul(inputs, self.quantum_weights[:, :, 1])
        
        # Magnitude (quantum probability amplitude inspired)
        output = tf.sqrt(real_part**2 + imag_part**2) + self.bias
        return tf.nn.relu(output)  # Non-linearity
    
    def get_config(self):
        config = super().get_config()
        config.update({"units": self.units})
        return config

def create_expert2_quantum_enhanced():
    """Expert 2 with quantum-enhanced layers (saves properly)"""
    model = tf.keras.Sequential([
        layers.InputLayer(input_shape=(SEQ_LEN, PATCH_SIZE, PATCH_SIZE, CHANNELS)),
        
        # Spatio-temporal processing
        layers.BatchNormalization(),
        layers.Conv3D(16, (3, 3, 3), activation='relu', padding='same'),
        layers.Conv3D(32, (2, 2, 2), activation='relu', padding='same'),
        layers.GlobalAveragePooling3D(),
        
        # Quantum-enhanced processing
        QuantumEnhancedLayer(64),
        layers.Dropout(0.2),
        QuantumEnhancedLayer(32),
        layers.BatchNormalization(),
        
        # Spatial reconstruction
        layers.Dense(PATCH_SIZE * PATCH_SIZE * 16, activation='relu'),
        layers.Reshape((PATCH_SIZE, PATCH_SIZE, 16)),
        
        # Final refinement
        layers.Conv2D(32, 3, activation='relu', padding='same'),
        layers.Conv2D(16, 3, activation='relu', padding='same'),
        layers.Conv2D(8, 3, activation='relu', padding='same'),
        layers.Conv2D(1, 3, activation='linear', padding='same')
    ], name="Expert2_QuantumEnhanced_PM10")
    
    return model

# ----------------------------
# Training Setup
# ----------------------------

def create_expert2_model():
    """Create Expert 2 model"""
    model = create_expert2_quantum_enhanced()
    
    optimizer = optimizers.Adam(learning_rate=LR)
    
    model.compile(
        optimizer=optimizer,
        loss='mse',
        metrics=['mae']
    )
    
    return model

def create_expert2_callbacks():
    """Create callbacks for training"""
    
    # Use TensorFlow SavedModel format
    checkpoint_cb = callbacks.ModelCheckpoint(
        os.path.join(OUTPUT_DIR, "expert2_best_model"),  # No .h5 extension
        monitor='val_loss',
        save_best_only=True,
        save_weights_only=False,
        save_format='tf',  # Use TensorFlow format
        mode='min',
        verbose=1
    )
    
    lr_scheduler = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )
    
    early_stopping = callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    )
    
    return [checkpoint_cb, lr_scheduler, early_stopping]

# ----------------------------
# Training Execution
# ----------------------------

def train_expert2():
    """Complete training pipeline for Expert 2"""
    print("\n" + "="*60)
    print("TRAINING EXPERT 2: Quantum-Enhanced PM10 Predictor")
    print("="*60)
    
    start_time = time.time()
    
    # Create model
    print("Creating Expert 2 model...")
    expert2 = create_expert2_model()
    
    print("\nModel Architecture:")
    expert2.summary()
    
    # Create callbacks
    callbacks_list = create_expert2_callbacks()
    
    print(f"\nTraining details:")
    print(f"  Samples: {len(X_train)} training, {len(X_val)} validation")
    print(f"  Input shape: ({SEQ_LEN}, {PATCH_SIZE}, {PATCH_SIZE}, {CHANNELS})")
    print(f"  Target shape: ({PATCH_SIZE}, {PATCH_SIZE}, 1)")
    print(f"  Model type: Quantum-Enhanced Sequential")
    print(f"  Epochs: {EPOCHS}, Batch size: {BATCH_SIZE}")
    
    # Train model
    print("\nStarting training...")
    history = expert2.fit(
        X_train, y_train_pm10,
        validation_data=(X_val, y_val_pm10),
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        callbacks=callbacks_list,
        verbose=1,
        shuffle=True
    )
    
    training_time = time.time() - start_time
    print(f"\nTraining completed in {training_time:.2f} seconds")
    
    return expert2, history, training_time  # RETURN training_time

# ----------------------------
# Evaluation
# ----------------------------

def evaluate_expert2(model, X_test, y_test):
    """Comprehensive evaluation of Expert 2"""
    print("\n" + "="*60)
    print("EVALUATING EXPERT 2")
    print("="*60)
    
    # Predictions
    y_pred = model.predict(X_test, batch_size=BATCH_SIZE, verbose=1)
    
    # Flatten for metric calculation
    y_true_flat = y_test.reshape(-1)
    y_pred_flat = y_pred.reshape(-1)
    
    # Remove any invalid values
    mask = ~(np.isnan(y_true_flat) | np.isnan(y_pred_flat) | np.isinf(y_true_flat) | np.isinf(y_pred_flat))
    y_true_flat = y_true_flat[mask]
    y_pred_flat = y_pred_flat[mask]
    
    # Regression metrics
    mse = mean_squared_error(y_true_flat, y_pred_flat)
    mae = mean_absolute_error(y_true_flat, y_pred_flat)
    r2 = r2_score(y_true_flat, y_pred_flat)
    
    print("\n📊 PERFORMANCE METRICS:")
    print(f"  MSE:  {mse:.4f}")
    print(f"  MAE:  {mae:.4f}")
    print(f"  R²:   {r2:.4f}")
    
    # Distribution analysis
    print("\n📈 DISTRIBUTION ANALYSIS:")
    print(f"  True - Min: {y_true_flat.min():.2f}, Max: {y_true_flat.max():.2f}, Mean: {y_true_flat.mean():.2f}")
    print(f"  Pred - Min: {y_pred_flat.min():.2f}, Max: {y_pred_flat.max():.2f}, Mean: {y_pred_flat.mean():.2f}")
    
    return {
        'mse': mse,
        'mae': mae, 
        'r2': r2,
        'predictions': y_pred,
        'y_true': y_true_flat,
        'y_pred': y_pred_flat
    }

# ----------------------------
# Visualization
# ----------------------------

def plot_expert2_results(history, evaluation_results):
    """Create visualization for Expert 2"""
    
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    # Loss plot
    axes[0,0].plot(history.history['loss'], label='Training Loss')
    axes[0,0].plot(history.history['val_loss'], label='Validation Loss')
    axes[0,0].set_title('Expert 2: Training and Validation Loss')
    axes[0,0].set_xlabel('Epoch')
    axes[0,0].set_ylabel('Loss')
    axes[0,0].legend()
    axes[0,0].grid(True)
    
    # MAE plot
    axes[0,1].plot(history.history['mae'], label='Training MAE')
    axes[0,1].plot(history.history['val_mae'], label='Validation MAE')
    axes[0,1].set_title('Expert 2: Training and Validation MAE')
    axes[0,1].set_xlabel('Epoch')
    axes[0,1].set_ylabel('MAE')
    axes[0,1].legend()
    axes[0,1].grid(True)
    
    # Prediction vs True scatter
    y_true = evaluation_results['y_true']
    y_pred = evaluation_results['y_pred']
    
    axes[1,0].scatter(y_true, y_pred, alpha=0.5, s=1)
    axes[1,0].plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'r--', lw=2)
    axes[1,0].set_xlabel('True PM10')
    axes[1,0].set_ylabel('Predicted PM10')
    axes[1,0].set_title(f'Predictions vs True (R² = {evaluation_results["r2"]:.3f})')
    axes[1,0].grid(True)
    
    # Error distribution
    errors = y_pred - y_true
    axes[1,1].hist(errors, bins=50, alpha=0.7, edgecolor='black')
    axes[1,1].axvline(x=0, color='r', linestyle='--')
    axes[1,1].set_xlabel('Prediction Error')
    axes[1,1].set_ylabel('Frequency')
    axes[1,1].set_title('Prediction Error Distribution')
    axes[1,1].grid(True)
    
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, 'expert2_results.png'), dpi=300, bbox_inches='tight')
    plt.show()

# ----------------------------
# Model Saving
# ----------------------------

def save_expert2_metadata(model, history, evaluation_results, training_time):
    """Save metadata and model for Expert 2"""
    
    metadata = {
        'expert_id': 1,
        'expert_name': 'QuantumEnhanced_PM10_Predictor',
        'architecture': {
            'type': 'Quantum-Enhanced Sequential',
            'input_shape': [SEQ_LEN, PATCH_SIZE, PATCH_SIZE, CHANNELS],
            'output_shape': [PATCH_SIZE, PATCH_SIZE, 1],
            'quantum_inspired': True
        },
        'training': {
            'epochs_trained': len(history.history['loss']),
            'final_train_loss': float(history.history['loss'][-1]),
            'final_val_loss': float(history.history['val_loss'][-1]),
            'training_time_seconds': float(training_time),
            'batch_size': BATCH_SIZE,
            'learning_rate': LR
        },
        'performance': {
            'test_mse': float(evaluation_results['mse']),
            'test_mae': float(evaluation_results['mae']),
            'test_r2': float(evaluation_results['r2'])
        },
        'target_band': 'PM10',
        'saved_format': 'TensorFlow SavedModel',
        'timestamp': time.strftime('%Y-%m-%d %H:%M:%S')
    }
    
    # Save metadata
    with open(os.path.join(OUTPUT_DIR, 'expert2_metadata.json'), 'w') as f:
        json.dump(metadata, f, indent=2)
    
    # Save final model in TensorFlow format
    model.save(os.path.join(OUTPUT_DIR, 'expert2_final_model'), save_format='tf')
    
    # Also save weights for compatibility
    model.save_weights(os.path.join(OUTPUT_DIR, 'expert2_weights.h5'))
    
    print(f"\n💾 Expert 2 saved successfully!")
    print(f"   Model: {OUTPUT_DIR}/expert2_final_model/ (TensorFlow format)")
    print(f"   Weights: {OUTPUT_DIR}/expert2_weights.h5")
    print(f"   Metadata: {OUTPUT_DIR}/expert2_metadata.json")

# ----------------------------
# Model Loading Function
# ----------------------------

def load_expert2_model():
    """Load trained Expert 2 model"""
    model_path = os.path.join(OUTPUT_DIR, 'expert2_final_model')
    if os.path.exists(model_path):
        return tf.keras.models.load_model(model_path, custom_objects={'QuantumEnhancedLayer': QuantumEnhancedLayer})
    else:
        print("Model not found. Please train first.")
        return None

# ----------------------------
# Main Execution
# ----------------------------

if __name__ == "__main__":
    print("🚀 STARTING EXPERT 2: Quantum-Enhanced PM10 Predictor")
    
    try:
        # Step 1: Train Expert 2
        expert2_model, training_history, training_time = train_expert2()  # CAPTURE training_time
        
        # Step 2: Evaluate Expert 2
        evaluation_results = evaluate_expert2(expert2_model, X_test, y_test_pm10)
        
        # Step 3: Visualize results
        plot_expert2_results(training_history, evaluation_results)
        
        # Step 4: Save model and metadata
        save_expert2_metadata(expert2_model, training_history, evaluation_results, training_time)
        
        print("\n✅ EXPERT 2 COMPLETED SUCCESSFULLY!")
        print("📁 Model ready for ensemble stacking!")
        
        # Test loading the model
        print("\n🧪 Testing model loading...")
        loaded_model = load_expert2_model()
        if loaded_model:
            print("✅ Model loaded successfully for ensemble integration!")
            
    except Exception as e:
        print(f"\n❌ ERROR in Expert 2: {e}")
        import traceback
        traceback.print_exc()
# Out:
# TensorFlow: 2.10.1
# PennyLane: 0.32.0
# Loaded shapes:
#  X_train: (994, 5, 10, 10, 24)
#  y_train: (994, 10, 10, 7)
#  X_val  : (213, 5, 10, 10, 24)
#  y_val  : (213, 10, 10, 7)
#  X_test : (214, 5, 10, 10, 24)
#  y_test : (214, 10, 10, 7)
# PM10 target shapes: (994, 10, 10, 1) (213, 10, 10, 1) (214, 10, 10, 1)
# 🚀 STARTING EXPERT 2: Quantum-Enhanced PM10 Predictor
#
# ============================================================
# TRAINING EXPERT 2: Quantum-Enhanced PM10 Predictor
# ============================================================
# Creating Expert 2 model...
#
# Model Architecture:
# Model: "Expert2_QuantumEnhanced_PM10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 5, 10, 10, 24)    96
#  ormalization)
#
#  conv3d (Conv3D)             (None, 5, 10, 10, 16)     10384
#
#  conv3d_1 (Conv3D)           (None, 5, 10, 10, 32)     4128
#
#  global_average_pooling3d (G  (None, 32)               0
#  lobalAveragePooling3D)
#
#  quantum_enhanced_layer (Qua  (None, 64)               4160
#  ntumEnhancedLayer)
#
#  dropout (Dropout)           (None, 64)                0
#
#  quantum_enhanced_layer_1 (Q  (None, 32)               4128
#  uantumEnhancedLayer)
#
#  batch_normalization_1 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense (Dense)               (None, 1600)              52800
#
#  reshape (Reshape)           (None, 10, 10, 16)        0
#
#  conv2d (Conv2D)             (None, 10, 10, 32)        4640
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 16)        4624
#
#  conv2d_2 (Conv2D)           (None, 10, 10, 8)         1160
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 1)         73
#
# =================================================================
# Total params: 86,321
# Trainable params: 86,209
# Non-trainable params: 112
# _________________________________________________________________
#
# Training details:
#   Samples: 994 training, 213 validation
#   Input shape: (5, 10, 10, 24)
#   Target shape: (10, 10, 1)
#   Model type: Quantum-Enhanced Sequential
#   Epochs: 100, Batch size: 4
#
# Starting training...
# Epoch 1/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0451 - mae: 0.1553
# Epoch 1: val_loss improved from inf to 0.04901, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model\assets
# 249/249 [==============================] - 17s 61ms/step - loss: 0.0449 - mae: 0.1548 - val_loss: 0.0490 - val_mae: 0.1549 - lr: 0.0010
# Epoch 2/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0296 - mae: 0.1248
# Epoch 2: val_loss improved from 0.04901 to 0.01188, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model\assets
# 249/249 [==============================] - 16s 63ms/step - loss: 0.0296 - mae: 0.1248 - val_loss: 0.0119 - val_mae: 0.0763 - lr: 0.0010
# Epoch 3/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0194 - mae: 0.1008
# Epoch 3: val_loss did not improve from 0.01188
# 249/249 [==============================] - 10s 40ms/step - loss: 0.0193 - mae: 0.1005 - val_loss: 0.0287 - val_mae: 0.1141 - lr: 0.0010
# Epoch 4/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0148 - mae: 0.0889
# Epoch 4: val_loss did not improve from 0.01188
# 249/249 [==============================] - 9s 37ms/step - loss: 0.0148 - mae: 0.0889 - val_loss: 0.0186 - val_mae: 0.0868 - lr: 0.0010
# Epoch 5/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0145 - mae: 0.0856
# Epoch 5: val_loss did not improve from 0.01188
# 249/249 [==============================] - 14s 55ms/step - loss: 0.0145 - mae: 0.0856 - val_loss: 0.0227 - val_mae: 0.0932 - lr: 0.0010
# Epoch 6/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0120 - mae: 0.0782
# Epoch 6: val_loss improved from 0.01188 to 0.00503, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model\assets
# 249/249 [==============================] - 20s 82ms/step - loss: 0.0121 - mae: 0.0788 - val_loss: 0.0050 - val_mae: 0.0549 - lr: 0.0010
# Epoch 7/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0098 - mae: 0.0725
# Epoch 7: val_loss did not improve from 0.00503
# 249/249 [==============================] - 10s 41ms/step - loss: 0.0098 - mae: 0.0725 - val_loss: 0.0069 - val_mae: 0.0624 - lr: 0.0010
# Epoch 8/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0093 - mae: 0.0708
# Epoch 8: val_loss improved from 0.00503 to 0.00389, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model\assets
# 249/249 [==============================] - 15s 60ms/step - loss: 0.0093 - mae: 0.0709 - val_loss: 0.0039 - val_mae: 0.0455 - lr: 0.0010
# Epoch 9/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0087 - mae: 0.0687
# Epoch 9: val_loss did not improve from 0.00389
# 249/249 [==============================] - 10s 38ms/step - loss: 0.0088 - mae: 0.0689 - val_loss: 0.0223 - val_mae: 0.0876 - lr: 0.0010
# Epoch 10/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0069 - mae: 0.0592
# Epoch 10: val_loss did not improve from 0.00389
# 249/249 [==============================] - 10s 42ms/step - loss: 0.0069 - mae: 0.0593 - val_loss: 0.0922 - val_mae: 0.1515 - lr: 0.0010
# Epoch 11/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0081 - mae: 0.0635
# Epoch 11: val_loss did not improve from 0.00389
# 249/249 [==============================] - 10s 40ms/step - loss: 0.0083 - mae: 0.0639 - val_loss: 0.0394 - val_mae: 0.0955 - lr: 0.0010
# Epoch 12/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0061 - mae: 0.0564
# Epoch 12: val_loss improved from 0.00389 to 0.00339, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model\assets
# 249/249 [==============================] - 14s 56ms/step - loss: 0.0061 - mae: 0.0565 - val_loss: 0.0034 - val_mae: 0.0452 - lr: 0.0010
# Epoch 13/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0056 - mae: 0.0547
# Epoch 13: val_loss did not improve from 0.00339
# 249/249 [==============================] - 9s 37ms/step - loss: 0.0056 - mae: 0.0547 - val_loss: 0.0327 - val_mae: 0.0936 - lr: 0.0010
# Epoch 14/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0049 - mae: 0.0513
# Epoch 14: val_loss did not improve from 0.00339
# 249/249 [==============================] - 9s 37ms/step - loss: 0.0049 - mae: 0.0513 - val_loss: 0.0122 - val_mae: 0.0591 - lr: 0.0010
# Epoch 15/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0048 - mae: 0.0504
# Epoch 15: val_loss did not improve from 0.00339
# 249/249 [==============================] - 10s 40ms/step - loss: 0.0049 - mae: 0.0508 - val_loss: 0.0144 - val_mae: 0.0669 - lr: 0.0010
# Epoch 16/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0058 - mae: 0.0535
# Epoch 16: val_loss did not improve from 0.00339
# 249/249 [==============================] - 14s 56ms/step - loss: 0.0058 - mae: 0.0535 - val_loss: 0.0104 - val_mae: 0.0574 - lr: 0.0010
# Epoch 17/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0062 - mae: 0.0550
# Epoch 17: val_loss did not improve from 0.00339
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 249/249 [==============================] - 14s 58ms/step - loss: 0.0062 - mae: 0.0551 - val_loss: 0.0334 - val_mae: 0.0909 - lr: 0.0010
# Epoch 18/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0036 - mae: 0.0439
# Epoch 18: val_loss did not improve from 0.00339
# 249/249 [==============================] - 12s 49ms/step - loss: 0.0036 - mae: 0.0439 - val_loss: 0.0046 - val_mae: 0.0412 - lr: 5.0000e-04
# Epoch 19/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0027 - mae: 0.0378
# Epoch 19: val_loss did not improve from 0.00339
# 249/249 [==============================] - 13s 53ms/step - loss: 0.0027 - mae: 0.0378 - val_loss: 0.0037 - val_mae: 0.0407 - lr: 5.0000e-04
# Epoch 20/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0032 - mae: 0.0396
# Epoch 20: val_loss improved from 0.00339 to 0.00193, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_best_model\assets
# 249/249 [==============================] - 22s 87ms/step - loss: 0.0032 - mae: 0.0396 - val_loss: 0.0019 - val_mae: 0.0321 - lr: 5.0000e-04
# Epoch 21/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0032 - mae: 0.0404
# Epoch 21: val_loss did not improve from 0.00193
# 249/249 [==============================] - 12s 49ms/step - loss: 0.0032 - mae: 0.0404 - val_loss: 0.0106 - val_mae: 0.0595 - lr: 5.0000e-04
# Epoch 22/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0032 - mae: 0.0393
# Epoch 22: val_loss did not improve from 0.00193
# 249/249 [==============================] - 13s 53ms/step - loss: 0.0032 - mae: 0.0393 - val_loss: 0.0025 - val_mae: 0.0361 - lr: 5.0000e-04
# Epoch 23/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0387
# Epoch 23: val_loss did not improve from 0.00193
# 249/249 [==============================] - 17s 68ms/step - loss: 0.0030 - mae: 0.0387 - val_loss: 0.0060 - val_mae: 0.0466 - lr: 5.0000e-04
# Epoch 24/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0031 - mae: 0.0384
# Epoch 24: val_loss did not improve from 0.00193
# 249/249 [==============================] - 15s 60ms/step - loss: 0.0032 - mae: 0.0385 - val_loss: 0.0112 - val_mae: 0.0571 - lr: 5.0000e-04
# Epoch 25/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0046 - mae: 0.0444
# Epoch 25: val_loss did not improve from 0.00193
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 249/249 [==============================] - 11s 42ms/step - loss: 0.0047 - mae: 0.0447 - val_loss: 0.0045 - val_mae: 0.0405 - lr: 5.0000e-04
# Epoch 26/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0025 - mae: 0.0359
# Epoch 26: val_loss did not improve from 0.00193
# 249/249 [==============================] - 8s 34ms/step - loss: 0.0025 - mae: 0.0359 - val_loss: 0.0032 - val_mae: 0.0347 - lr: 2.5000e-04
# Epoch 27/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0019 - mae: 0.0319
# Epoch 27: val_loss did not improve from 0.00193
# 249/249 [==============================] - 8s 34ms/step - loss: 0.0019 - mae: 0.0319 - val_loss: 0.0044 - val_mae: 0.0403 - lr: 2.5000e-04
# Epoch 28/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0020 - mae: 0.0322
# Epoch 28: val_loss did not improve from 0.00193
# 249/249 [==============================] - 11s 43ms/step - loss: 0.0020 - mae: 0.0322 - val_loss: 0.0037 - val_mae: 0.0359 - lr: 2.5000e-04
# Epoch 29/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0020 - mae: 0.0309
# Epoch 29: val_loss did not improve from 0.00193
# 249/249 [==============================] - 10s 39ms/step - loss: 0.0021 - mae: 0.0312 - val_loss: 0.0044 - val_mae: 0.0429 - lr: 2.5000e-04
# Epoch 30/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0314
# Epoch 30: val_loss did not improve from 0.00193
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Restoring model weights from the end of the best epoch: 20.
# 249/249 [==============================] - 10s 42ms/step - loss: 0.0018 - mae: 0.0314 - val_loss: 0.0038 - val_mae: 0.0373 - lr: 2.5000e-04
# Epoch 30: early stopping
#
# Training completed in 375.47 seconds
#
# ============================================================
# EVALUATING EXPERT 2
# ============================================================
# 54/54 [==============================] - 1s 9ms/step
#
# 📊 PERFORMANCE METRICS:
#   MSE:  0.0019
#   MAE:  0.0301
#   R²:   0.9551
#
# 📈 DISTRIBUTION ANALYSIS:
#   True - Min: 0.00, Max: 0.99, Mean: 0.45
#   Pred - Min: -0.13, Max: 1.16, Mean: 0.46
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_final_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output\expert2_final_model\assets
# 💾 Expert 2 saved successfully!
#    Model: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output/expert2_final_model/ (TensorFlow format)
#    Weights: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output/expert2_weights.h5
#    Metadata: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert2_output/expert2_metadata.json
#
# ✅ EXPERT 2 COMPLETED SUCCESSFULLY!
# 📁 Model ready for ensemble stacking!
#
# 🧪 Testing model loading...
# ✅ Model loaded successfully for ensemble integration!
