# %%
# Expert 17: Advanced Quantum-Enhanced NO2 Predictor
# Using TensorFlow SavedModel format for subclassed models

import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''  # comment out to enable GPU

import time
import json
import numpy as np
import pennylane as qml
import tensorflow as tf
from tensorflow.keras import layers, Model, optimizers, callbacks
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# ----------------------------
# CONFIG
# ----------------------------
DATA_DIR = r"C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\datasets"
OUTPUT_DIR = r"C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output"
os.makedirs(OUTPUT_DIR, exist_ok=True)

SEQ_LEN = 5
PATCH_SIZE = 10
CHANNELS = 24
PRED_BAND_IDX = 2  # Changed to 2 for NO2
NUM_QUBITS = 4
Q_DEPTH = 2
EPOCHS = 100
BATCH_SIZE = 4
LR = 1e-3

np.random.seed(42)
tf.random.set_seed(42)

print("TensorFlow:", tf.__version__)
print("PennyLane:", qml.__version__)

# ----------------------------
# Load datasets
# ----------------------------

def load_npy(name):
    path = os.path.join(DATA_DIR, name)
    if not os.path.exists(path):
        raise FileNotFoundError(path)
    return np.load(path)

X_train = load_npy("X_train.npy")
y_train = load_npy("y_train.npy")
X_val = load_npy("X_val.npy")
y_val = load_npy("y_val.npy")
X_test = load_npy("X_test.npy")
y_test = load_npy("y_test.npy")

print("Loaded shapes:")
print(" X_train:", X_train.shape)
print(" y_train:", y_train.shape)
print(" X_val  :", X_val.shape)
print(" y_val  :", y_val.shape)
print(" X_test :", X_test.shape)
print(" y_test :", y_test.shape)

# Prepare NO2 targets
def extract_no2(y):
    no2 = y[..., PRED_BAND_IDX]
    return no2[..., None].astype(np.float32)

y_train_no2 = extract_no2(y_train)
y_val_no2 = extract_no2(y_val)
y_test_no2 = extract_no2(y_test)

print("NO2 target shapes:", y_train_no2.shape, y_val_no2.shape, y_test_no2.shape)

# ----------------------------
# Advanced Quantum-Enhanced Layer
# ----------------------------

class AdvancedQuantumLayer(layers.Layer):
    """Advanced quantum-inspired layer with entanglement simulation"""
    
    def __init__(self, units, use_entanglement=True, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.use_entanglement = use_entanglement
        
    def build(self, input_shape):
        # Quantum-inspired weights with complex representation
        self.quantum_weights_real = self.add_weight(
            shape=(input_shape[-1], self.units),
            initializer='glorot_uniform',
            trainable=True,
            name='quantum_weights_real'
        )
        self.quantum_weights_imag = self.add_weight(
            shape=(input_shape[-1], self.units),
            initializer='glorot_uniform',
            trainable=True,
            name='quantum_weights_imag'
        )
        
        # Entanglement simulation weights
        if self.use_entanglement:
            self.entanglement_weights = self.add_weight(
                shape=(self.units, self.units),
                initializer='orthogonal',
                trainable=True,
                name='entanglement_weights'
            )
        
        self.bias = self.add_weight(
            shape=(self.units,),
            initializer='zeros',
            trainable=True,
            name='bias'
        )
        super().build(input_shape)
    
    def call(self, inputs):
        # Quantum-inspired transformation with complex operations
        real_part = tf.matmul(inputs, self.quantum_weights_real)
        imag_part = tf.matmul(inputs, self.quantum_weights_imag)
        
        # Quantum probability amplitude
        magnitude = tf.sqrt(real_part**2 + imag_part**2 + 1e-8)
        
        # Entanglement simulation
        if self.use_entanglement:
            entangled = tf.matmul(magnitude, self.entanglement_weights)
            magnitude = 0.7 * magnitude + 0.3 * entangled
        
        # Quantum-inspired activation
        output = magnitude + self.bias
        return tf.nn.swish(output)  # Smooth activation
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "units": self.units,
            "use_entanglement": self.use_entanglement
        })
        return config

# ----------------------------
# Attention Mechanisms
# ----------------------------

class TemporalAttention(layers.Layer):
    """Temporal attention for sequence processing"""
    
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        
    def build(self, input_shape):
        self.query = layers.Dense(self.units)
        self.key = layers.Dense(self.units)
        self.value = layers.Dense(self.units)
        super().build(input_shape)
    
    def call(self, inputs):
        # inputs shape: (batch, seq_len, features)
        q = self.query(inputs)
        k = self.key(inputs)
        v = self.value(inputs)
        
        # Scaled dot-product attention
        scores = tf.matmul(q, k, transpose_b=True)
        scores = scores / tf.math.sqrt(tf.cast(self.units, tf.float32))
        attention_weights = tf.nn.softmax(scores, axis=-1)
        
        # Apply attention
        output = tf.matmul(attention_weights, v)
        return output

class SpatialAttention(layers.Layer):
    """Spatial attention for patch processing"""
    
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        
    def build(self, input_shape):
        self.conv1 = layers.Conv2D(1, 1, activation='sigmoid')
        super().build(input_shape)
    
    def call(self, inputs):
        # inputs shape: (batch, height, width, channels)
        attention_weights = self.conv1(inputs)
        return inputs * attention_weights

# ----------------------------
# Expert 17 Model Architecture
# ----------------------------

def create_expert17_advanced_quantum():
    """Expert 17 with advanced quantum-enhanced architecture for NO2 prediction"""
    
    inputs = layers.Input(shape=(SEQ_LEN, PATCH_SIZE, PATCH_SIZE, CHANNELS))
    
    # Initial processing
    x = layers.BatchNormalization()(inputs)
    
    # Temporal processing branch
    temporal_branch = layers.TimeDistributed(
        layers.Conv2D(32, 3, activation='relu', padding='same')
    )(x)
    temporal_branch = layers.TimeDistributed(
        layers.Conv2D(64, 3, activation='relu', padding='same')
    )(temporal_branch)
    temporal_branch = layers.TimeDistributed(
        layers.MaxPooling2D(2)
    )(temporal_branch)  # Output: (batch, seq_len, 5, 5, 64)
    
    # Spatial processing branch
    spatial_branch = layers.Reshape((SEQ_LEN, PATCH_SIZE * PATCH_SIZE, CHANNELS))(x)
    spatial_branch = layers.Permute((2, 1, 3))(spatial_branch)  # (batch, 100, 5, 24)
    spatial_branch = layers.Reshape((PATCH_SIZE * PATCH_SIZE, SEQ_LEN * CHANNELS))(spatial_branch)  # (batch, 100, 120)
    
    # Apply temporal attention
    temporal_attention = TemporalAttention(units=64)(spatial_branch)
    temporal_attention = layers.Dense(128, activation='relu')(temporal_attention)
    temporal_attention = layers.Dropout(0.3)(temporal_attention)
    
    # Reshape back to spatial dimensions
    temporal_attention = layers.Reshape((PATCH_SIZE, PATCH_SIZE, 128))(temporal_attention)
    
    # Advanced quantum-enhanced processing
    quantum_features = layers.GlobalAveragePooling3D()(temporal_branch)
    quantum_features = AdvancedQuantumLayer(256, use_entanglement=True)(quantum_features)
    quantum_features = layers.Dropout(0.2)(quantum_features)
    quantum_features = AdvancedQuantumLayer(128, use_entanglement=False)(quantum_features)
    
    # Expand quantum features to spatial dimensions
    quantum_expanded = layers.Dense(PATCH_SIZE * PATCH_SIZE * 64)(quantum_features)
    quantum_expanded = layers.Reshape((PATCH_SIZE, PATCH_SIZE, 64))(quantum_expanded)
    
    # Combine branches
    combined = layers.Concatenate()([temporal_attention, quantum_expanded])
    
    # Spatial attention
    combined = SpatialAttention()(combined)
    
    # MODIFIED REFINEMENT LAYERS
    # Added depthwise separable convolutions for better efficiency
    x = layers.SeparableConv2D(128, 3, activation='relu', padding='same')(combined)
    x = layers.BatchNormalization()(x)
    
    # Added residual connection
    residual = layers.Conv2D(128, 1, padding='same')(combined)
    x = layers.Add()([x, residual])
    x = layers.Activation('relu')(x)
    
    # Main processing path
    x = layers.Conv2D(96, 3, activation='relu', padding='same')(x)  # Changed from 64 to 96
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.25)(x)  # Slightly increased dropout
    
    # Added depthwise convolution
    x = layers.DepthwiseConv2D(3, padding='same', activation='relu')(x)
    x = layers.Conv2D(64, 1, activation='relu')(x)  # Pointwise convolution
    
    # Modified: Reduced number of layers for efficiency
    x = layers.Conv2D(48, 3, activation='relu', padding='same')(x)  # Changed from 32 to 48
    x = layers.BatchNormalization()(x)
    
    # Final processing
    x = layers.Conv2D(32, 3, activation='relu', padding='same')(x)
    x = layers.Dropout(0.2)(x)
    
    # Final output
    outputs = layers.Conv2D(1, 3, activation='linear', padding='same')(x)
    
    model = Model(inputs=inputs, outputs=outputs, name="Expert17_Advanced_Quantum_NO2")
    return model

# ----------------------------
# Training Setup
# ----------------------------

def create_expert17_model():
    """Create Expert 17 model"""
    model = create_expert17_advanced_quantum()
    
    # Use standard Adam optimizer instead of AdamW
    optimizer = optimizers.Adam(learning_rate=LR)
    
    model.compile(
        optimizer=optimizer,
        loss='mse',
        metrics=['mae', 'mse']
    )
    
    return model

def create_expert17_callbacks():
    """Create callbacks for training Expert 17"""
    
    checkpoint_cb = callbacks.ModelCheckpoint(
        os.path.join(OUTPUT_DIR, "expert17_best_model"),
        monitor='val_loss',
        save_best_only=True,
        save_weights_only=False,
        save_format='tf',
        mode='min',
        verbose=1
    )
    
    lr_scheduler = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )
    
    early_stopping = callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    )
    
    tensorboard = callbacks.TensorBoard(
        log_dir=os.path.join(OUTPUT_DIR, 'logs'),
        update_freq='epoch'
    )
    
    return [checkpoint_cb, lr_scheduler, early_stopping, tensorboard]

# ----------------------------
# Training Execution
# ----------------------------

def train_expert17():
    """Complete training pipeline for Expert 17"""
    print("\n" + "="*60)
    print("TRAINING EXPERT 17: Advanced Quantum-Enhanced NO2 Predictor")
    print("="*60)
    
    start_time = time.time()
    
    # Create model
    print("Creating Expert 17 model...")
    expert17 = create_expert17_model()
    
    print("\nModel Architecture:")
    expert17.summary()
    
    # Create callbacks
    callbacks_list = create_expert17_callbacks()
    
    print(f"\nTraining details:")
    print(f"  Samples: {len(X_train)} training, {len(X_val)} validation")
    print(f"  Input shape: ({SEQ_LEN}, {PATCH_SIZE}, {PATCH_SIZE}, {CHANNELS})")
    print(f"  Target shape: ({PATCH_SIZE}, {PATCH_SIZE}, 1)")
    print(f"  Model type: Advanced Quantum-Enhanced with Attention")
    print(f"  Epochs: {EPOCHS}, Batch size: {BATCH_SIZE}")
    print(f"  Features: Temporal Attention, Spatial Attention, Quantum Entanglement")
    print(f"  Target parameter: NO2 (Nitrogen Dioxide, band index {PRED_BAND_IDX})")
    print(f"  Architecture modifications: Added residual connections, depthwise separable convs")
    
    # Train model
    print("\nStarting training...")
    history = expert17.fit(
        X_train, y_train_no2,
        validation_data=(X_val, y_val_no2),
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        callbacks=callbacks_list,
        verbose=1,
        shuffle=True
    )
    
    training_time = time.time() - start_time
    print(f"\nTraining completed in {training_time:.2f} seconds")
    
    return expert17, history, training_time

# ----------------------------
# Evaluation
# ----------------------------

def evaluate_expert17(model, X_test, y_test):
    """Comprehensive evaluation of Expert 17"""
    print("\n" + "="*60)
    print("EVALUATING EXPERT 17")
    print("="*60)
    
    # Predictions
    y_pred = model.predict(X_test, batch_size=BATCH_SIZE, verbose=1)
    
    # Flatten for metric calculation
    y_true_flat = y_test.reshape(-1)
    y_pred_flat = y_pred.reshape(-1)
    
    # Remove any invalid values
    mask = ~(np.isnan(y_true_flat) | np.isnan(y_pred_flat) | np.isinf(y_true_flat) | np.isinf(y_pred_flat))
    y_true_flat = y_true_flat[mask]
    y_pred_flat = y_pred_flat[mask]
    
    # Regression metrics
    mse = mean_squared_error(y_true_flat, y_pred_flat)
    mae = mean_absolute_error(y_true_flat, y_pred_flat)
    r2 = r2_score(y_true_flat, y_pred_flat)
    
    print("\n📊 PERFORMANCE METRICS:")
    print(f"  MSE:  {mse:.4f}")
    print(f"  MAE:  {mae:.4f}")
    print(f"  R²:   {r2:.4f}")
    
    # Distribution analysis
    print("\n📈 DISTRIBUTION ANALYSIS:")
    print(f"  True - Min: {y_true_flat.min():.2f}, Max: {y_true_flat.max():.2f}, Mean: {y_true_flat.mean():.2f}")
    print(f"  Pred - Min: {y_pred_flat.min():.2f}, Max: {y_pred_flat.max():.2f}, Mean: {y_pred_flat.mean():.2f}")
    
    return {
        'mse': mse,
        'mae': mae, 
        'r2': r2,
        'predictions': y_pred,
        'y_true': y_true_flat,
        'y_pred': y_pred_flat
    }

# ----------------------------
# Visualization
# ----------------------------

def plot_expert17_results(history, evaluation_results):
    """Create visualization for Expert 17"""
    
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    # Loss plot
    axes[0,0].plot(history.history['loss'], label='Training Loss')
    axes[0,0].plot(history.history['val_loss'], label='Validation Loss')
    axes[0,0].set_title('Expert 17: Training and Validation Loss')
    axes[0,0].set_xlabel('Epoch')
    axes[0,0].set_ylabel('Loss')
    axes[0,0].legend()
    axes[0,0].grid(True)
    
    # MAE plot
    axes[0,1].plot(history.history['mae'], label='Training MAE')
    axes[0,1].plot(history.history['val_mae'], label='Validation MAE')
    axes[0,1].set_title('Expert 17: Training and Validation MAE')
    axes[0,1].set_xlabel('Epoch')
    axes[0,1].set_ylabel('MAE')
    axes[0,1].legend()
    axes[0,1].grid(True)
    
    # Prediction vs True scatter
    y_true = evaluation_results['y_true']
    y_pred = evaluation_results['y_pred']
    
    axes[1,0].scatter(y_true, y_pred, alpha=0.5, s=1)
    axes[1,0].plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'r--', lw=2)
    axes[1,0].set_xlabel('True NO2')
    axes[1,0].set_ylabel('Predicted NO2')
    axes[1,0].set_title(f'Predictions vs True (R² = {evaluation_results["r2"]:.3f})')
    axes[1,0].grid(True)
    
    # Error distribution
    errors = y_pred - y_true
    axes[1,1].hist(errors, bins=50, alpha=0.7, edgecolor='black')
    axes[1,1].axvline(x=0, color='r', linestyle='--')
    axes[1,1].set_xlabel('Prediction Error')
    axes[1,1].set_ylabel('Frequency')
    axes[1,1].set_title('Prediction Error Distribution')
    axes[1,1].grid(True)
    
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, 'expert17_results.png'), dpi=300, bbox_inches='tight')
    plt.show()

# ----------------------------
# Model Saving
# ----------------------------

def save_expert17_metadata(model, history, evaluation_results, training_time):
    """Save metadata and model for Expert 17"""
    
    metadata = {
        'expert_id': 17,
        'expert_name': 'Advanced_Quantum_Enhanced_NO2_Predictor',
        'architecture': {
            'type': 'Advanced Quantum-Enhanced with Attention',
            'input_shape': [SEQ_LEN, PATCH_SIZE, PATCH_SIZE, CHANNELS],
            'output_shape': [PATCH_SIZE, PATCH_SIZE, 1],
            'features': [
                'Temporal Attention', 
                'Spatial Attention', 
                'Quantum Entanglement', 
                'Advanced Quantum Layers',
                'Residual Connections',
                'Depthwise Separable Convolutions',
                'Modified Refinement Layers'
            ]
        },
        'training': {
            'epochs_trained': len(history.history['loss']),
            'final_train_loss': float(history.history['loss'][-1]),
            'final_val_loss': float(history.history['val_loss'][-1]),
            'training_time_seconds': float(training_time),
            'batch_size': BATCH_SIZE,
            'learning_rate': LR
        },
        'performance': {
            'test_mse': float(evaluation_results['mse']),
            'test_mae': float(evaluation_results['mae']),
            'test_r2': float(evaluation_results['r2'])
        },
        'target_band': 'NO2',
        'target_band_index': PRED_BAND_IDX,
        'saved_format': 'TensorFlow SavedModel',
        'timestamp': time.strftime('%Y-%m-%d %H:%M:%S')
    }
    
    # Save metadata
    with open(os.path.join(OUTPUT_DIR, 'expert17_metadata.json'), 'w') as f:
        json.dump(metadata, f, indent=2)
    
    # Save final model in TensorFlow format
    model.save(os.path.join(OUTPUT_DIR, 'expert17_final_model'), save_format='tf')
    
    # Also save weights for compatibility
    model.save_weights(os.path.join(OUTPUT_DIR, 'expert17_weights.h5'))
    
    print(f"\n💾 Expert 17 saved successfully!")
    print(f"   Model: {OUTPUT_DIR}/expert17_final_model/ (TensorFlow format)")
    print(f"   Weights: {OUTPUT_DIR}/expert17_weights.h5")
    print(f"   Metadata: {OUTPUT_DIR}/expert17_metadata.json")

# ----------------------------
# Model Loading Function
# ----------------------------

def load_expert17_model():
    """Load trained Expert 17 model"""
    model_path = os.path.join(OUTPUT_DIR, 'expert17_final_model')
    if os.path.exists(model_path):
        return tf.keras.models.load_model(
            model_path, 
            custom_objects={
                'AdvancedQuantumLayer': AdvancedQuantumLayer,
                'TemporalAttention': TemporalAttention,
                'SpatialAttention': SpatialAttention
            }
        )
    else:
        print("Model not found. Please train first.")
        return None

# ----------------------------
# Main Execution
# ----------------------------

if __name__ == "__main__":
    print("🚀 STARTING EXPERT 17: Advanced Quantum-Enhanced NO2 Predictor")
    
    try:
        # Step 1: Train Expert 17
        expert17_model, training_history, training_time = train_expert17()
        
        # Step 2: Evaluate Expert 17
        evaluation_results = evaluate_expert17(expert17_model, X_test, y_test_no2)
        
        # Step 3: Visualize results
        plot_expert17_results(training_history, evaluation_results)
        
        # Step 4: Save model and metadata
        save_expert17_metadata(expert17_model, training_history, evaluation_results, training_time)
        
        print("\n✅ EXPERT 17 COMPLETED SUCCESSFULLY!")
        print("📁 Model ready for ensemble stacking!")
        
        # Test loading the model
        print("\n🧪 Testing model loading...")
        loaded_model = load_expert17_model()
        if loaded_model:
            print("✅ Model loaded successfully for ensemble integration!")
            
    except Exception as e:
        print(f"\n❌ ERROR in Expert 17: {e}")
        import traceback
        traceback.print_exc()
# Out:
# TensorFlow: 2.10.1
# PennyLane: 0.32.0
# Loaded shapes:
#  X_train: (994, 5, 10, 10, 24)
#  y_train: (994, 10, 10, 7)
#  X_val  : (213, 5, 10, 10, 24)
#  y_val  : (213, 10, 10, 7)
#  X_test : (214, 5, 10, 10, 24)
#  y_test : (214, 10, 10, 7)
# NO2 target shapes: (994, 10, 10, 1) (213, 10, 10, 1) (214, 10, 10, 1)
# 🚀 STARTING EXPERT 17: Advanced Quantum-Enhanced NO2 Predictor
#
# ============================================================
# TRAINING EXPERT 17: Advanced Quantum-Enhanced NO2 Predictor
# ============================================================
# Creating Expert 17 model...
#
# Model Architecture:
# Model: "Expert17_Advanced_Quantum_NO2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 5, 10, 10,   0           []
#                                 24)]
#
#  batch_normalization (BatchNorm  (None, 5, 10, 10, 2  96         ['input_1[0][0]']
#  alization)                     4)
#
#  time_distributed (TimeDistribu  (None, 5, 10, 10, 3  6944       ['batch_normalization[0][0]']
#  ted)                           2)
#
#  time_distributed_1 (TimeDistri  (None, 5, 10, 10, 6  18496      ['time_distributed[0][0]']
#  buted)                         4)
#
#  reshape (Reshape)              (None, 5, 100, 24)   0           ['batch_normalization[0][0]']
#
#  time_distributed_2 (TimeDistri  (None, 5, 5, 5, 64)  0          ['time_distributed_1[0][0]']
#  buted)
#
#  permute (Permute)              (None, 100, 5, 24)   0           ['reshape[0][0]']
#
#  global_average_pooling3d (Glob  (None, 64)          0           ['time_distributed_2[0][0]']
#  alAveragePooling3D)
#
#  reshape_1 (Reshape)            (None, 100, 120)     0           ['permute[0][0]']
#
#  advanced_quantum_layer (Advanc  (None, 256)         98560       ['global_average_pooling3d[0][0]'
#  edQuantumLayer)                                                 ]
#
#  temporal_attention (TemporalAt  (None, 100, 64)     23232       ['reshape_1[0][0]']
#  tention)
#
#  dropout_1 (Dropout)            (None, 256)          0           ['advanced_quantum_layer[0][0]']
#
#  dense (Dense)                  (None, 100, 128)     8320        ['temporal_attention[0][0]']
#
#  advanced_quantum_layer_1 (Adva  (None, 128)         65664       ['dropout_1[0][0]']
#  ncedQuantumLayer)
#
#  dropout (Dropout)              (None, 100, 128)     0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 6400)         825600      ['advanced_quantum_layer_1[0][0]'
#                                                                  ]
#
#  reshape_2 (Reshape)            (None, 10, 10, 128)  0           ['dropout[0][0]']
#
#  reshape_3 (Reshape)            (None, 10, 10, 64)   0           ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 10, 10, 192)  0           ['reshape_2[0][0]',
#                                                                   'reshape_3[0][0]']
#
#  spatial_attention (SpatialAtte  (None, 10, 10, 192)  193        ['concatenate[0][0]']
#  ntion)
#
#  separable_conv2d (SeparableCon  (None, 10, 10, 128)  26432      ['spatial_attention[0][0]']
#  v2D)
#
#  batch_normalization_1 (BatchNo  (None, 10, 10, 128)  512        ['separable_conv2d[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 10, 10, 128)  24704       ['spatial_attention[0][0]']
#
#  add (Add)                      (None, 10, 10, 128)  0           ['batch_normalization_1[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  activation (Activation)        (None, 10, 10, 128)  0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 10, 10, 96)   110688      ['activation[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 10, 10, 96)  384         ['conv2d_3[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 10, 10, 96)   0           ['batch_normalization_2[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (None, 10, 10, 96)  960         ['dropout_2[0][0]']
#  v2D)
#
#  conv2d_4 (Conv2D)              (None, 10, 10, 64)   6208        ['depthwise_conv2d[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 10, 10, 48)   27696       ['conv2d_4[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 10, 10, 48)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  conv2d_6 (Conv2D)              (None, 10, 10, 32)   13856       ['batch_normalization_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 10, 10, 32)   0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 10, 10, 1)    289         ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 1,259,026
# Trainable params: 1,258,434
# Non-trainable params: 592
# __________________________________________________________________________________________________
#
# Training details:
#   Samples: 994 training, 213 validation
#   Input shape: (5, 10, 10, 24)
#   Target shape: (10, 10, 1)
#   Model type: Advanced Quantum-Enhanced with Attention
#   Epochs: 100, Batch size: 4
#   Features: Temporal Attention, Spatial Attention, Quantum Entanglement
#   Target parameter: NO2 (Nitrogen Dioxide, band index 2)
#   Architecture modifications: Added residual connections, depthwise separable convs
#
# Starting training...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Layer TemporalAttention has arguments ['units']
# in `__init__` and therefore must override `get_config()`.
#
# Example:
#
# class CustomLayer(keras.layers.Layer):
#     def __init__(self, arg1, arg2):
#         super().__init__()
#         self.arg1 = arg1
#         self.arg2 = arg2
#
#     def get_config(self):
#         config = super().get_config()
#         config.update({
#             "arg1": self.arg1,
#             "arg2": self.arg2,
#         })
#         return config
# Epoch 1/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0412 - mae: 0.1376 - mse: 0.0412
# Epoch 1: val_loss improved from inf to 0.03409, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# 249/249 [==============================] - 40s 140ms/step - loss: 0.0412 - mae: 0.1376 - mse: 0.0412 - val_loss: 0.0341 - val_mae: 0.1365 - val_mse: 0.0341 - lr: 0.0010
# Epoch 2/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0161 - mae: 0.0963 - mse: 0.0161
# Epoch 2: val_loss improved from 0.03409 to 0.02714, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# 249/249 [==============================] - 40s 162ms/step - loss: 0.0161 - mae: 0.0963 - mse: 0.0161 - val_loss: 0.0271 - val_mae: 0.1225 - val_mse: 0.0271 - lr: 0.0010
# Epoch 3/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0141 - mae: 0.0882 - mse: 0.0141
# Epoch 3: val_loss improved from 0.02714 to 0.00675, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# 249/249 [==============================] - 30s 119ms/step - loss: 0.0141 - mae: 0.0881 - mse: 0.0141 - val_loss: 0.0067 - val_mae: 0.0638 - val_mse: 0.0067 - lr: 0.0010
# Epoch 4/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0092 - mae: 0.0722 - mse: 0.0092
# Epoch 4: val_loss improved from 0.00675 to 0.00403, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# 249/249 [==============================] - 52s 210ms/step - loss: 0.0092 - mae: 0.0722 - mse: 0.0092 - val_loss: 0.0040 - val_mae: 0.0513 - val_mse: 0.0040 - lr: 0.0010
# Epoch 5/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0071 - mae: 0.0649 - mse: 0.0071
# Epoch 5: val_loss improved from 0.00403 to 0.00365, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# 249/249 [==============================] - 53s 213ms/step - loss: 0.0071 - mae: 0.0649 - mse: 0.0071 - val_loss: 0.0037 - val_mae: 0.0477 - val_mse: 0.0037 - lr: 0.0010
# Epoch 6/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0056 - mae: 0.0571 - mse: 0.0056
# Epoch 6: val_loss improved from 0.00365 to 0.00309, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# 249/249 [==============================] - 64s 259ms/step - loss: 0.0056 - mae: 0.0570 - mse: 0.0056 - val_loss: 0.0031 - val_mae: 0.0449 - val_mse: 0.0031 - lr: 0.0010
# Epoch 7/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0054 - mae: 0.0552 - mse: 0.0054
# Epoch 7: val_loss improved from 0.00309 to 0.00264, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# 249/249 [==============================] - 42s 168ms/step - loss: 0.0054 - mae: 0.0552 - mse: 0.0054 - val_loss: 0.0026 - val_mae: 0.0410 - val_mse: 0.0026 - lr: 0.0010
# Epoch 8/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0057 - mae: 0.0568 - mse: 0.0057
# Epoch 8: val_loss did not improve from 0.00264
# 249/249 [==============================] - 13s 52ms/step - loss: 0.0057 - mae: 0.0567 - mse: 0.0057 - val_loss: 0.0038 - val_mae: 0.0463 - val_mse: 0.0038 - lr: 0.0010
# Epoch 9/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0046 - mae: 0.0512 - mse: 0.0046
# Epoch 9: val_loss did not improve from 0.00264
# 249/249 [==============================] - 11s 43ms/step - loss: 0.0046 - mae: 0.0512 - mse: 0.0046 - val_loss: 0.0026 - val_mae: 0.0398 - val_mse: 0.0026 - lr: 0.0010
# Epoch 10/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0047 - mae: 0.0504 - mse: 0.0047
# Epoch 10: val_loss improved from 0.00264 to 0.00174, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# 249/249 [==============================] - 30s 121ms/step - loss: 0.0047 - mae: 0.0504 - mse: 0.0047 - val_loss: 0.0017 - val_mae: 0.0306 - val_mse: 0.0017 - lr: 0.0010
# Epoch 11/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0036 - mae: 0.0450 - mse: 0.0036
# Epoch 11: val_loss did not improve from 0.00174
# 249/249 [==============================] - 24s 96ms/step - loss: 0.0036 - mae: 0.0450 - mse: 0.0036 - val_loss: 0.0045 - val_mae: 0.0529 - val_mse: 0.0045 - lr: 0.0010
# Epoch 12/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0037 - mae: 0.0448 - mse: 0.0037
# Epoch 12: val_loss did not improve from 0.00174
# 249/249 [==============================] - 17s 70ms/step - loss: 0.0036 - mae: 0.0448 - mse: 0.0036 - val_loss: 0.0025 - val_mae: 0.0371 - val_mse: 0.0025 - lr: 0.0010
# Epoch 13/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0036 - mae: 0.0438 - mse: 0.0036
# Epoch 13: val_loss did not improve from 0.00174
# 249/249 [==============================] - 13s 54ms/step - loss: 0.0036 - mae: 0.0438 - mse: 0.0036 - val_loss: 0.0025 - val_mae: 0.0384 - val_mse: 0.0025 - lr: 0.0010
# Epoch 14/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0035 - mae: 0.0441 - mse: 0.0035
# Epoch 14: val_loss did not improve from 0.00174
# 249/249 [==============================] - 14s 58ms/step - loss: 0.0035 - mae: 0.0441 - mse: 0.0035 - val_loss: 0.0032 - val_mae: 0.0446 - val_mse: 0.0032 - lr: 0.0010
# Epoch 15/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0429 - mse: 0.0034
# Epoch 15: val_loss did not improve from 0.00174
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 249/249 [==============================] - 13s 53ms/step - loss: 0.0034 - mae: 0.0429 - mse: 0.0034 - val_loss: 0.0026 - val_mae: 0.0389 - val_mse: 0.0026 - lr: 0.0010
# Epoch 16/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0024 - mae: 0.0362 - mse: 0.0024
# Epoch 16: val_loss did not improve from 0.00174
# 249/249 [==============================] - 19s 77ms/step - loss: 0.0024 - mae: 0.0362 - mse: 0.0024 - val_loss: 0.0018 - val_mae: 0.0338 - val_mse: 0.0018 - lr: 5.0000e-04
# Epoch 17/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0024 - mae: 0.0358 - mse: 0.0024
# Epoch 17: val_loss improved from 0.00174 to 0.00117, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# 249/249 [==============================] - 65s 262ms/step - loss: 0.0025 - mae: 0.0360 - mse: 0.0025 - val_loss: 0.0012 - val_mae: 0.0248 - val_mse: 0.0012 - lr: 5.0000e-04
# Epoch 18/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0026 - mae: 0.0367 - mse: 0.0026
# Epoch 18: val_loss did not improve from 0.00117
# 249/249 [==============================] - 30s 119ms/step - loss: 0.0026 - mae: 0.0367 - mse: 0.0026 - val_loss: 0.0036 - val_mae: 0.0464 - val_mse: 0.0036 - lr: 5.0000e-04
# Epoch 19/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0025 - mae: 0.0363 - mse: 0.0025
# Epoch 19: val_loss did not improve from 0.00117
# 249/249 [==============================] - 21s 83ms/step - loss: 0.0025 - mae: 0.0363 - mse: 0.0025 - val_loss: 0.0028 - val_mae: 0.0394 - val_mse: 0.0028 - lr: 5.0000e-04
# Epoch 20/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0022 - mae: 0.0344 - mse: 0.0022
# Epoch 20: val_loss did not improve from 0.00117
# 249/249 [==============================] - 16s 63ms/step - loss: 0.0022 - mae: 0.0344 - mse: 0.0022 - val_loss: 0.0016 - val_mae: 0.0298 - val_mse: 0.0016 - lr: 5.0000e-04
# Epoch 21/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0024 - mae: 0.0351 - mse: 0.0024
# Epoch 21: val_loss improved from 0.00117 to 0.00084, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# 249/249 [==============================] - 39s 159ms/step - loss: 0.0024 - mae: 0.0351 - mse: 0.0024 - val_loss: 8.4209e-04 - val_mae: 0.0217 - val_mse: 8.4209e-04 - lr: 5.0000e-04
# Epoch 22/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0021 - mae: 0.0336 - mse: 0.0021
# Epoch 22: val_loss did not improve from 0.00084
# 249/249 [==============================] - 18s 73ms/step - loss: 0.0021 - mae: 0.0336 - mse: 0.0021 - val_loss: 0.0012 - val_mae: 0.0257 - val_mse: 0.0012 - lr: 5.0000e-04
# Epoch 23/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0022 - mae: 0.0341 - mse: 0.0022
# Epoch 23: val_loss did not improve from 0.00084
# 249/249 [==============================] - 20s 79ms/step - loss: 0.0022 - mae: 0.0340 - mse: 0.0022 - val_loss: 0.0012 - val_mae: 0.0272 - val_mse: 0.0012 - lr: 5.0000e-04
# Epoch 24/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0022 - mae: 0.0340 - mse: 0.0022
# Epoch 24: val_loss did not improve from 0.00084
# 249/249 [==============================] - 14s 58ms/step - loss: 0.0022 - mae: 0.0340 - mse: 0.0022 - val_loss: 0.0014 - val_mae: 0.0276 - val_mse: 0.0014 - lr: 5.0000e-04
# Epoch 25/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0020 - mae: 0.0332 - mse: 0.0020
# Epoch 25: val_loss did not improve from 0.00084
# 249/249 [==============================] - 11s 44ms/step - loss: 0.0020 - mae: 0.0332 - mse: 0.0020 - val_loss: 0.0017 - val_mae: 0.0291 - val_mse: 0.0017 - lr: 5.0000e-04
# Epoch 26/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0021 - mae: 0.0333 - mse: 0.0021
# Epoch 26: val_loss did not improve from 0.00084
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 249/249 [==============================] - 11s 43ms/step - loss: 0.0021 - mae: 0.0334 - mse: 0.0021 - val_loss: 0.0011 - val_mae: 0.0248 - val_mse: 0.0011 - lr: 5.0000e-04
# Epoch 27/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0016 - mae: 0.0295 - mse: 0.0016
# Epoch 27: val_loss did not improve from 0.00084
# 249/249 [==============================] - 12s 46ms/step - loss: 0.0016 - mae: 0.0296 - mse: 0.0016 - val_loss: 0.0013 - val_mae: 0.0251 - val_mse: 0.0013 - lr: 2.5000e-04
# Epoch 28/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0018 - mae: 0.0305 - mse: 0.0018
# Epoch 28: val_loss did not improve from 0.00084
# 249/249 [==============================] - 12s 50ms/step - loss: 0.0018 - mae: 0.0305 - mse: 0.0018 - val_loss: 0.0011 - val_mae: 0.0239 - val_mse: 0.0011 - lr: 2.5000e-04
# Epoch 29/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0016 - mae: 0.0290 - mse: 0.0016
# Epoch 29: val_loss did not improve from 0.00084
# 249/249 [==============================] - 12s 49ms/step - loss: 0.0016 - mae: 0.0290 - mse: 0.0016 - val_loss: 0.0014 - val_mae: 0.0290 - val_mse: 0.0014 - lr: 2.5000e-04
# Epoch 30/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0016 - mae: 0.0290 - mse: 0.0016
# Epoch 30: val_loss did not improve from 0.00084
# 249/249 [==============================] - 12s 50ms/step - loss: 0.0016 - mae: 0.0290 - mse: 0.0016 - val_loss: 0.0015 - val_mae: 0.0277 - val_mse: 0.0015 - lr: 2.5000e-04
# Epoch 31/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0015 - mae: 0.0290 - mse: 0.0015
# Epoch 31: val_loss improved from 0.00084 to 0.00072, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# 249/249 [==============================] - 20s 81ms/step - loss: 0.0015 - mae: 0.0291 - mse: 0.0015 - val_loss: 7.1758e-04 - val_mae: 0.0193 - val_mse: 7.1758e-04 - lr: 2.5000e-04
# Epoch 32/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0015 - mae: 0.0279 - mse: 0.0015
# Epoch 32: val_loss did not improve from 0.00072
# 249/249 [==============================] - 12s 50ms/step - loss: 0.0015 - mae: 0.0279 - mse: 0.0015 - val_loss: 7.4194e-04 - val_mae: 0.0195 - val_mse: 7.4194e-04 - lr: 2.5000e-04
# Epoch 33/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0016 - mae: 0.0287 - mse: 0.0016
# Epoch 33: val_loss did not improve from 0.00072
# 249/249 [==============================] - 12s 49ms/step - loss: 0.0016 - mae: 0.0287 - mse: 0.0016 - val_loss: 0.0015 - val_mae: 0.0264 - val_mse: 0.0015 - lr: 2.5000e-04
# Epoch 34/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0015 - mae: 0.0285 - mse: 0.0015
# Epoch 34: val_loss did not improve from 0.00072
# 249/249 [==============================] - 12s 47ms/step - loss: 0.0015 - mae: 0.0285 - mse: 0.0015 - val_loss: 8.3237e-04 - val_mae: 0.0221 - val_mse: 8.3237e-04 - lr: 2.5000e-04
# Epoch 35/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0014 - mae: 0.0276 - mse: 0.0014
# Epoch 35: val_loss did not improve from 0.00072
# 249/249 [==============================] - 8s 32ms/step - loss: 0.0014 - mae: 0.0276 - mse: 0.0014 - val_loss: 7.9627e-04 - val_mae: 0.0191 - val_mse: 7.9627e-04 - lr: 2.5000e-04
# Epoch 36/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0017 - mae: 0.0301 - mse: 0.0017
# Epoch 36: val_loss did not improve from 0.00072
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 249/249 [==============================] - 13s 52ms/step - loss: 0.0017 - mae: 0.0301 - mse: 0.0017 - val_loss: 0.0013 - val_mae: 0.0255 - val_mse: 0.0013 - lr: 2.5000e-04
# Epoch 37/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0011 - mae: 0.0245 - mse: 0.0011
# Epoch 37: val_loss did not improve from 0.00072
# 249/249 [==============================] - 12s 49ms/step - loss: 0.0011 - mae: 0.0245 - mse: 0.0011 - val_loss: 7.8161e-04 - val_mae: 0.0208 - val_mse: 7.8161e-04 - lr: 1.2500e-04
# Epoch 38/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0265 - mse: 0.0014
# Epoch 38: val_loss did not improve from 0.00072
# 249/249 [==============================] - 11s 44ms/step - loss: 0.0014 - mae: 0.0265 - mse: 0.0014 - val_loss: 9.5027e-04 - val_mae: 0.0223 - val_mse: 9.5027e-04 - lr: 1.2500e-04
# Epoch 39/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0259 - mse: 0.0012
# Epoch 39: val_loss improved from 0.00072 to 0.00066, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# 249/249 [==============================] - 19s 76ms/step - loss: 0.0012 - mae: 0.0258 - mse: 0.0012 - val_loss: 6.6368e-04 - val_mae: 0.0186 - val_mse: 6.6368e-04 - lr: 1.2500e-04
# Epoch 40/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0012 - mae: 0.0254 - mse: 0.0012
# Epoch 40: val_loss did not improve from 0.00066
# 249/249 [==============================] - 10s 42ms/step - loss: 0.0012 - mae: 0.0254 - mse: 0.0012 - val_loss: 9.7119e-04 - val_mae: 0.0239 - val_mse: 9.7119e-04 - lr: 1.2500e-04
# Epoch 41/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0252 - mse: 0.0012
# Epoch 41: val_loss improved from 0.00066 to 0.00053, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_best_model\assets
# 249/249 [==============================] - 19s 75ms/step - loss: 0.0012 - mae: 0.0251 - mse: 0.0012 - val_loss: 5.3208e-04 - val_mae: 0.0169 - val_mse: 5.3208e-04 - lr: 1.2500e-04
# Epoch 42/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0251 - mse: 0.0012
# Epoch 42: val_loss did not improve from 0.00053
# 249/249 [==============================] - 10s 40ms/step - loss: 0.0012 - mae: 0.0251 - mse: 0.0012 - val_loss: 7.6729e-04 - val_mae: 0.0191 - val_mse: 7.6729e-04 - lr: 1.2500e-04
# Epoch 43/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0011 - mae: 0.0245 - mse: 0.0011
# Epoch 43: val_loss did not improve from 0.00053
# 249/249 [==============================] - 11s 43ms/step - loss: 0.0011 - mae: 0.0245 - mse: 0.0011 - val_loss: 5.8802e-04 - val_mae: 0.0186 - val_mse: 5.8802e-04 - lr: 1.2500e-04
# Epoch 44/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0011 - mae: 0.0235 - mse: 0.0011
# Epoch 44: val_loss did not improve from 0.00053
# 249/249 [==============================] - 11s 44ms/step - loss: 0.0011 - mae: 0.0235 - mse: 0.0011 - val_loss: 5.7003e-04 - val_mae: 0.0180 - val_mse: 5.7003e-04 - lr: 1.2500e-04
# Epoch 45/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0011 - mae: 0.0243 - mse: 0.0011
# Epoch 45: val_loss did not improve from 0.00053
# 249/249 [==============================] - 14s 57ms/step - loss: 0.0011 - mae: 0.0243 - mse: 0.0011 - val_loss: 6.6059e-04 - val_mae: 0.0185 - val_mse: 6.6059e-04 - lr: 1.2500e-04
# Epoch 46/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0011 - mae: 0.0245 - mse: 0.0011
# Epoch 46: val_loss did not improve from 0.00053
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 249/249 [==============================] - 11s 44ms/step - loss: 0.0011 - mae: 0.0245 - mse: 0.0011 - val_loss: 5.7032e-04 - val_mae: 0.0159 - val_mse: 5.7032e-04 - lr: 1.2500e-04
# Epoch 47/100
# 248/249 [============================>.] - ETA: 0s - loss: 9.8358e-04 - mae: 0.0230 - mse: 9.8358e-04
# Epoch 47: val_loss did not improve from 0.00053
# 249/249 [==============================] - 10s 41ms/step - loss: 9.8743e-04 - mae: 0.0231 - mse: 9.8743e-04 - val_loss: 5.8624e-04 - val_mae: 0.0171 - val_mse: 5.8624e-04 - lr: 6.2500e-05
# Epoch 48/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0011 - mae: 0.0235 - mse: 0.0011
# Epoch 48: val_loss did not improve from 0.00053
# 249/249 [==============================] - 12s 50ms/step - loss: 0.0011 - mae: 0.0235 - mse: 0.0011 - val_loss: 7.5221e-04 - val_mae: 0.0190 - val_mse: 7.5221e-04 - lr: 6.2500e-05
# Epoch 49/100
# 249/249 [==============================] - ETA: 0s - loss: 9.6076e-04 - mae: 0.0226 - mse: 9.6076e-04
# Epoch 49: val_loss did not improve from 0.00053
# 249/249 [==============================] - 11s 45ms/step - loss: 9.6076e-04 - mae: 0.0226 - mse: 9.6076e-04 - val_loss: 6.8062e-04 - val_mae: 0.0178 - val_mse: 6.8062e-04 - lr: 6.2500e-05
# Epoch 50/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0010 - mae: 0.0232 - mse: 0.0010
# Epoch 50: val_loss did not improve from 0.00053
# 249/249 [==============================] - 11s 45ms/step - loss: 0.0010 - mae: 0.0231 - mse: 0.0010 - val_loss: 6.1227e-04 - val_mae: 0.0162 - val_mse: 6.1227e-04 - lr: 6.2500e-05
# Epoch 51/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0010 - mae: 0.0229 - mse: 0.0010
# Epoch 51: val_loss did not improve from 0.00053
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Restoring model weights from the end of the best epoch: 41.
# 249/249 [==============================] - 12s 47ms/step - loss: 0.0010 - mae: 0.0229 - mse: 0.0010 - val_loss: 8.0280e-04 - val_mae: 0.0199 - val_mse: 8.0280e-04 - lr: 6.2500e-05
# Epoch 51: early stopping
#
# Training completed in 1033.98 seconds
#
# ============================================================
# EVALUATING EXPERT 17
# ============================================================
# 54/54 [==============================] - 1s 16ms/step
#
# 📊 PERFORMANCE METRICS:
#   MSE:  0.0004
#   MAE:  0.0152
#   R²:   0.9797
#
# 📈 DISTRIBUTION ANALYSIS:
#   True - Min: 0.00, Max: 0.79, Mean: 0.18
#   Pred - Min: -0.02, Max: 0.88, Mean: 0.17
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_final_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output\expert17_final_model\assets
# 💾 Expert 17 saved successfully!
#    Model: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output/expert17_final_model/ (TensorFlow format)
#    Weights: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output/expert17_weights.h5
#    Metadata: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert17_output/expert17_metadata.json
#
# ✅ EXPERT 17 COMPLETED SUCCESSFULLY!
# 📁 Model ready for ensemble stacking!
#
# 🧪 Testing model loading...
# ✅ Model loaded successfully for ensemble integration!
