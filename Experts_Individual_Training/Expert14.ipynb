# %%
# Expert 14: Advanced Quantum-Enhanced AOD Predictor
# Using TensorFlow SavedModel format for subclassed models

import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''  # comment out to enable GPU

import time
import json
import numpy as np
import pennylane as qml
import tensorflow as tf
from tensorflow.keras import layers, Model, optimizers, callbacks
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# ----------------------------
# CONFIG
# ----------------------------
DATA_DIR = r"C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\datasets"
OUTPUT_DIR = r"C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output"
os.makedirs(OUTPUT_DIR, exist_ok=True)

SEQ_LEN = 5
PATCH_SIZE = 10
CHANNELS = 24
PRED_BAND_IDX = 6  # Changed to 6 for AOD
NUM_QUBITS = 4
Q_DEPTH = 2
EPOCHS = 100
BATCH_SIZE = 4
LR = 1e-3

np.random.seed(42)
tf.random.set_seed(42)

print("TensorFlow:", tf.__version__)
print("PennyLane:", qml.__version__)

# ----------------------------
# Load datasets
# ----------------------------

def load_npy(name):
    path = os.path.join(DATA_DIR, name)
    if not os.path.exists(path):
        raise FileNotFoundError(path)
    return np.load(path)

X_train = load_npy("X_train.npy")
y_train = load_npy("y_train.npy")
X_val = load_npy("X_val.npy")
y_val = load_npy("y_val.npy")
X_test = load_npy("X_test.npy")
y_test = load_npy("y_test.npy")

print("Loaded shapes:")
print(" X_train:", X_train.shape)
print(" y_train:", y_train.shape)
print(" X_val  :", X_val.shape)
print(" y_val  :", y_val.shape)
print(" X_test :", X_test.shape)
print(" y_test :", y_test.shape)

# Prepare AOD targets
def extract_aod(y):
    aod = y[..., PRED_BAND_IDX]
    return aod[..., None].astype(np.float32)

y_train_aod = extract_aod(y_train)
y_val_aod = extract_aod(y_val)
y_test_aod = extract_aod(y_test)

print("AOD target shapes:", y_train_aod.shape, y_val_aod.shape, y_test_aod.shape)

# ----------------------------
# Advanced Quantum-Enhanced Layer
# ----------------------------

class AdvancedQuantumLayer(layers.Layer):
    """Advanced quantum-inspired layer with entanglement simulation"""
    
    def __init__(self, units, use_entanglement=True, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.use_entanglement = use_entanglement
        
    def build(self, input_shape):
        # Quantum-inspired weights with complex representation
        self.quantum_weights_real = self.add_weight(
            shape=(input_shape[-1], self.units),
            initializer='glorot_uniform',
            trainable=True,
            name='quantum_weights_real'
        )
        self.quantum_weights_imag = self.add_weight(
            shape=(input_shape[-1], self.units),
            initializer='glorot_uniform',
            trainable=True,
            name='quantum_weights_imag'
        )
        
        # Entanglement simulation weights
        if self.use_entanglement:
            self.entanglement_weights = self.add_weight(
                shape=(self.units, self.units),
                initializer='orthogonal',
                trainable=True,
                name='entanglement_weights'
            )
        
        self.bias = self.add_weight(
            shape=(self.units,),
            initializer='zeros',
            trainable=True,
            name='bias'
        )
        super().build(input_shape)
    
    def call(self, inputs):
        # Quantum-inspired transformation with complex operations
        real_part = tf.matmul(inputs, self.quantum_weights_real)
        imag_part = tf.matmul(inputs, self.quantum_weights_imag)
        
        # Quantum probability amplitude
        magnitude = tf.sqrt(real_part**2 + imag_part**2 + 1e-8)
        
        # Entanglement simulation
        if self.use_entanglement:
            entangled = tf.matmul(magnitude, self.entanglement_weights)
            magnitude = 0.7 * magnitude + 0.3 * entangled
        
        # Quantum-inspired activation
        output = magnitude + self.bias
        return tf.nn.swish(output)  # Smooth activation
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "units": self.units,
            "use_entanglement": self.use_entanglement
        })
        return config

# ----------------------------
# Attention Mechanisms
# ----------------------------

class TemporalAttention(layers.Layer):
    """Temporal attention for sequence processing"""
    
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        
    def build(self, input_shape):
        self.query = layers.Dense(self.units)
        self.key = layers.Dense(self.units)
        self.value = layers.Dense(self.units)
        super().build(input_shape)
    
    def call(self, inputs):
        # inputs shape: (batch, seq_len, features)
        q = self.query(inputs)
        k = self.key(inputs)
        v = self.value(inputs)
        
        # Scaled dot-product attention
        scores = tf.matmul(q, k, transpose_b=True)
        scores = scores / tf.math.sqrt(tf.cast(self.units, tf.float32))
        attention_weights = tf.nn.softmax(scores, axis=-1)
        
        # Apply attention
        output = tf.matmul(attention_weights, v)
        return output

class SpatialAttention(layers.Layer):
    """Spatial attention for patch processing"""
    
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        
    def build(self, input_shape):
        self.conv1 = layers.Conv2D(1, 1, activation='sigmoid')
        super().build(input_shape)
    
    def call(self, inputs):
        # inputs shape: (batch, height, width, channels)
        attention_weights = self.conv1(inputs)
        return inputs * attention_weights

# ----------------------------
# Expert 14 Model Architecture
# ----------------------------

def create_expert14_advanced_quantum():
    """Expert 14 with advanced quantum-enhanced architecture for AOD prediction"""
    
    inputs = layers.Input(shape=(SEQ_LEN, PATCH_SIZE, PATCH_SIZE, CHANNELS))
    
    # Initial processing
    x = layers.BatchNormalization()(inputs)
    
    # Temporal processing branch
    temporal_branch = layers.TimeDistributed(
        layers.Conv2D(32, 3, activation='relu', padding='same')
    )(x)
    temporal_branch = layers.TimeDistributed(
        layers.Conv2D(64, 3, activation='relu', padding='same')
    )(temporal_branch)
    temporal_branch = layers.TimeDistributed(
        layers.MaxPooling2D(2)
    )(temporal_branch)  # Output: (batch, seq_len, 5, 5, 64)
    
    # Spatial processing branch
    spatial_branch = layers.Reshape((SEQ_LEN, PATCH_SIZE * PATCH_SIZE, CHANNELS))(x)
    spatial_branch = layers.Permute((2, 1, 3))(spatial_branch)  # (batch, 100, 5, 24)
    spatial_branch = layers.Reshape((PATCH_SIZE * PATCH_SIZE, SEQ_LEN * CHANNELS))(spatial_branch)  # (batch, 100, 120)
    
    # Apply temporal attention
    temporal_attention = TemporalAttention(units=64)(spatial_branch)
    temporal_attention = layers.Dense(128, activation='relu')(temporal_attention)
    temporal_attention = layers.Dropout(0.3)(temporal_attention)
    
    # Reshape back to spatial dimensions
    temporal_attention = layers.Reshape((PATCH_SIZE, PATCH_SIZE, 128))(temporal_attention)
    
    # Advanced quantum-enhanced processing
    quantum_features = layers.GlobalAveragePooling3D()(temporal_branch)
    quantum_features = AdvancedQuantumLayer(256, use_entanglement=True)(quantum_features)
    quantum_features = layers.Dropout(0.2)(quantum_features)
    quantum_features = AdvancedQuantumLayer(128, use_entanglement=False)(quantum_features)
    
    # Expand quantum features to spatial dimensions
    quantum_expanded = layers.Dense(PATCH_SIZE * PATCH_SIZE * 64)(quantum_features)
    quantum_expanded = layers.Reshape((PATCH_SIZE, PATCH_SIZE, 64))(quantum_expanded)
    
    # Combine branches
    combined = layers.Concatenate()([temporal_attention, quantum_expanded])
    
    # Spatial attention
    combined = SpatialAttention()(combined)
    
    # Refinement layers
    x = layers.Conv2D(128, 3, activation='relu', padding='same')(combined)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(64, 3, activation='relu', padding='same')(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Conv2D(32, 3, activation='relu', padding='same')(x)
    x = layers.Conv2D(16, 3, activation='relu', padding='same')(x)
    
    # Final output
    outputs = layers.Conv2D(1, 3, activation='linear', padding='same')(x)
    
    model = Model(inputs=inputs, outputs=outputs, name="Expert14_Advanced_Quantum_AOD")
    return model

# ----------------------------
# Training Setup
# ----------------------------

def create_expert14_model():
    """Create Expert 14 model"""
    model = create_expert14_advanced_quantum()
    
    # Use standard Adam optimizer instead of AdamW
    optimizer = optimizers.Adam(learning_rate=LR)
    
    model.compile(
        optimizer=optimizer,
        loss='mse',
        metrics=['mae', 'mse']
    )
    
    return model

def create_expert14_callbacks():
    """Create callbacks for training Expert 14"""
    
    checkpoint_cb = callbacks.ModelCheckpoint(
        os.path.join(OUTPUT_DIR, "expert14_best_model"),
        monitor='val_loss',
        save_best_only=True,
        save_weights_only=False,
        save_format='tf',
        mode='min',
        verbose=1
    )
    
    lr_scheduler = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )
    
    early_stopping = callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    )
    
    tensorboard = callbacks.TensorBoard(
        log_dir=os.path.join(OUTPUT_DIR, 'logs'),
        update_freq='epoch'
    )
    
    return [checkpoint_cb, lr_scheduler, early_stopping, tensorboard]

# ----------------------------
# Training Execution
# ----------------------------

def train_expert14():
    """Complete training pipeline for Expert 14"""
    print("\n" + "="*60)
    print("TRAINING EXPERT 14: Advanced Quantum-Enhanced AOD Predictor")
    print("="*60)
    
    start_time = time.time()
    
    # Create model
    print("Creating Expert 14 model...")
    expert14 = create_expert14_model()
    
    print("\nModel Architecture:")
    expert14.summary()
    
    # Create callbacks
    callbacks_list = create_expert14_callbacks()
    
    print(f"\nTraining details:")
    print(f"  Samples: {len(X_train)} training, {len(X_val)} validation")
    print(f"  Input shape: ({SEQ_LEN}, {PATCH_SIZE}, {PATCH_SIZE}, {CHANNELS})")
    print(f"  Target shape: ({PATCH_SIZE}, {PATCH_SIZE}, 1)")
    print(f"  Model type: Advanced Quantum-Enhanced with Attention")
    print(f"  Epochs: {EPOCHS}, Batch size: {BATCH_SIZE}")
    print(f"  Features: Temporal Attention, Spatial Attention, Quantum Entanglement")
    print(f"  Target parameter: AOD (Aerosol Optical Depth, band index {PRED_BAND_IDX})")
    
    # Train model
    print("\nStarting training...")
    history = expert14.fit(
        X_train, y_train_aod,
        validation_data=(X_val, y_val_aod),
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        callbacks=callbacks_list,
        verbose=1,
        shuffle=True
    )
    
    training_time = time.time() - start_time
    print(f"\nTraining completed in {training_time:.2f} seconds")
    
    return expert14, history, training_time

# ----------------------------
# Evaluation
# ----------------------------

def evaluate_expert14(model, X_test, y_test):
    """Comprehensive evaluation of Expert 14"""
    print("\n" + "="*60)
    print("EVALUATING EXPERT 14")
    print("="*60)
    
    # Predictions
    y_pred = model.predict(X_test, batch_size=BATCH_SIZE, verbose=1)
    
    # Flatten for metric calculation
    y_true_flat = y_test.reshape(-1)
    y_pred_flat = y_pred.reshape(-1)
    
    # Remove any invalid values
    mask = ~(np.isnan(y_true_flat) | np.isnan(y_pred_flat) | np.isinf(y_true_flat) | np.isinf(y_pred_flat))
    y_true_flat = y_true_flat[mask]
    y_pred_flat = y_pred_flat[mask]
    
    # Regression metrics
    mse = mean_squared_error(y_true_flat, y_pred_flat)
    mae = mean_absolute_error(y_true_flat, y_pred_flat)
    r2 = r2_score(y_true_flat, y_pred_flat)
    
    print("\n📊 PERFORMANCE METRICS:")
    print(f"  MSE:  {mse:.4f}")
    print(f"  MAE:  {mae:.4f}")
    print(f"  R²:   {r2:.4f}")
    
    # Distribution analysis
    print("\n📈 DISTRIBUTION ANALYSIS:")
    print(f"  True - Min: {y_true_flat.min():.2f}, Max: {y_true_flat.max():.2f}, Mean: {y_true_flat.mean():.2f}")
    print(f"  Pred - Min: {y_pred_flat.min():.2f}, Max: {y_pred_flat.max():.2f}, Mean: {y_pred_flat.mean():.2f}")
    
    return {
        'mse': mse,
        'mae': mae, 
        'r2': r2,
        'predictions': y_pred,
        'y_true': y_true_flat,
        'y_pred': y_pred_flat
    }

# ----------------------------
# Visualization
# ----------------------------

def plot_expert14_results(history, evaluation_results):
    """Create visualization for Expert 14"""
    
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    # Loss plot
    axes[0,0].plot(history.history['loss'], label='Training Loss')
    axes[0,0].plot(history.history['val_loss'], label='Validation Loss')
    axes[0,0].set_title('Expert 14: Training and Validation Loss')
    axes[0,0].set_xlabel('Epoch')
    axes[0,0].set_ylabel('Loss')
    axes[0,0].legend()
    axes[0,0].grid(True)
    
    # MAE plot
    axes[0,1].plot(history.history['mae'], label='Training MAE')
    axes[0,1].plot(history.history['val_mae'], label='Validation MAE')
    axes[0,1].set_title('Expert 14: Training and Validation MAE')
    axes[0,1].set_xlabel('Epoch')
    axes[0,1].set_ylabel('MAE')
    axes[0,1].legend()
    axes[0,1].grid(True)
    
    # Prediction vs True scatter
    y_true = evaluation_results['y_true']
    y_pred = evaluation_results['y_pred']
    
    axes[1,0].scatter(y_true, y_pred, alpha=0.5, s=1)
    axes[1,0].plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'r--', lw=2)
    axes[1,0].set_xlabel('True AOD')
    axes[1,0].set_ylabel('Predicted AOD')
    axes[1,0].set_title(f'Predictions vs True (R² = {evaluation_results["r2"]:.3f})')
    axes[1,0].grid(True)
    
    # Error distribution
    errors = y_pred - y_true
    axes[1,1].hist(errors, bins=50, alpha=0.7, edgecolor='black')
    axes[1,1].axvline(x=0, color='r', linestyle='--')
    axes[1,1].set_xlabel('Prediction Error')
    axes[1,1].set_ylabel('Frequency')
    axes[1,1].set_title('Prediction Error Distribution')
    axes[1,1].grid(True)
    
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, 'expert14_results.png'), dpi=300, bbox_inches='tight')
    plt.show()

# ----------------------------
# Model Saving
# ----------------------------

def save_expert14_metadata(model, history, evaluation_results, training_time):
    """Save metadata and model for Expert 14"""
    
    metadata = {
        'expert_id': 14,
        'expert_name': 'Advanced_Quantum_Enhanced_AOD_Predictor',
        'architecture': {
            'type': 'Advanced Quantum-Enhanced with Attention',
            'input_shape': [SEQ_LEN, PATCH_SIZE, PATCH_SIZE, CHANNELS],
            'output_shape': [PATCH_SIZE, PATCH_SIZE, 1],
            'features': ['Temporal Attention', 'Spatial Attention', 'Quantum Entanglement', 'Advanced Quantum Layers']
        },
        'training': {
            'epochs_trained': len(history.history['loss']),
            'final_train_loss': float(history.history['loss'][-1]),
            'final_val_loss': float(history.history['val_loss'][-1]),
            'training_time_seconds': float(training_time),
            'batch_size': BATCH_SIZE,
            'learning_rate': LR
        },
        'performance': {
            'test_mse': float(evaluation_results['mse']),
            'test_mae': float(evaluation_results['mae']),
            'test_r2': float(evaluation_results['r2'])
        },
        'target_band': 'AOD',
        'target_band_index': PRED_BAND_IDX,
        'saved_format': 'TensorFlow SavedModel',
        'timestamp': time.strftime('%Y-%m-%d %H:%M:%S')
    }
    
    # Save metadata
    with open(os.path.join(OUTPUT_DIR, 'expert14_metadata.json'), 'w') as f:
        json.dump(metadata, f, indent=2)
    
    # Save final model in TensorFlow format
    model.save(os.path.join(OUTPUT_DIR, 'expert14_final_model'), save_format='tf')
    
    # Also save weights for compatibility
    model.save_weights(os.path.join(OUTPUT_DIR, 'expert14_weights.h5'))
    
    print(f"\n💾 Expert 14 saved successfully!")
    print(f"   Model: {OUTPUT_DIR}/expert14_final_model/ (TensorFlow format)")
    print(f"   Weights: {OUTPUT_DIR}/expert14_weights.h5")
    print(f"   Metadata: {OUTPUT_DIR}/expert14_metadata.json")

# ----------------------------
# Model Loading Function
# ----------------------------

def load_expert14_model():
    """Load trained Expert 14 model"""
    model_path = os.path.join(OUTPUT_DIR, 'expert14_final_model')
    if os.path.exists(model_path):
        return tf.keras.models.load_model(
            model_path, 
            custom_objects={
                'AdvancedQuantumLayer': AdvancedQuantumLayer,
                'TemporalAttention': TemporalAttention,
                'SpatialAttention': SpatialAttention
            }
        )
    else:
        print("Model not found. Please train first.")
        return None

# ----------------------------
# Main Execution
# ----------------------------

if __name__ == "__main__":
    print("🚀 STARTING EXPERT 14: Advanced Quantum-Enhanced AOD Predictor")
    
    try:
        # Step 1: Train Expert 14
        expert14_model, training_history, training_time = train_expert14()
        
        # Step 2: Evaluate Expert 14
        evaluation_results = evaluate_expert14(expert14_model, X_test, y_test_aod)
        
        # Step 3: Visualize results
        plot_expert14_results(training_history, evaluation_results)
        
        # Step 4: Save model and metadata
        save_expert14_metadata(expert14_model, training_history, evaluation_results, training_time)
        
        print("\n✅ EXPERT 14 COMPLETED SUCCESSFULLY!")
        print("📁 Model ready for ensemble stacking!")
        
        # Test loading the model
        print("\n🧪 Testing model loading...")
        loaded_model = load_expert14_model()
        if loaded_model:
            print("✅ Model loaded successfully for ensemble integration!")
            
    except Exception as e:
        print(f"\n❌ ERROR in Expert 14: {e}")
        import traceback
        traceback.print_exc()
# Out:
# TensorFlow: 2.10.1
# PennyLane: 0.32.0
# Loaded shapes:
#  X_train: (994, 5, 10, 10, 24)
#  y_train: (994, 10, 10, 7)
#  X_val  : (213, 5, 10, 10, 24)
#  y_val  : (213, 10, 10, 7)
#  X_test : (214, 5, 10, 10, 24)
#  y_test : (214, 10, 10, 7)
# AOD target shapes: (994, 10, 10, 1) (213, 10, 10, 1) (214, 10, 10, 1)
# 🚀 STARTING EXPERT 14: Advanced Quantum-Enhanced AOD Predictor
#
# ============================================================
# TRAINING EXPERT 14: Advanced Quantum-Enhanced AOD Predictor
# ============================================================
# Creating Expert 14 model...
#
# Model Architecture:
# Model: "Expert14_Advanced_Quantum_AOD"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 5, 10, 10,   0           []
#                                 24)]
#
#  batch_normalization (BatchNorm  (None, 5, 10, 10, 2  96         ['input_1[0][0]']
#  alization)                     4)
#
#  time_distributed (TimeDistribu  (None, 5, 10, 10, 3  6944       ['batch_normalization[0][0]']
#  ted)                           2)
#
#  time_distributed_1 (TimeDistri  (None, 5, 10, 10, 6  18496      ['time_distributed[0][0]']
#  buted)                         4)
#
#  reshape (Reshape)              (None, 5, 100, 24)   0           ['batch_normalization[0][0]']
#
#  time_distributed_2 (TimeDistri  (None, 5, 5, 5, 64)  0          ['time_distributed_1[0][0]']
#  buted)
#
#  permute (Permute)              (None, 100, 5, 24)   0           ['reshape[0][0]']
#
#  global_average_pooling3d (Glob  (None, 64)          0           ['time_distributed_2[0][0]']
#  alAveragePooling3D)
#
#  reshape_1 (Reshape)            (None, 100, 120)     0           ['permute[0][0]']
#
#  advanced_quantum_layer (Advanc  (None, 256)         98560       ['global_average_pooling3d[0][0]'
#  edQuantumLayer)                                                 ]
#
#  temporal_attention (TemporalAt  (None, 100, 64)     23232       ['reshape_1[0][0]']
#  tention)
#
#  dropout_1 (Dropout)            (None, 256)          0           ['advanced_quantum_layer[0][0]']
#
#  dense (Dense)                  (None, 100, 128)     8320        ['temporal_attention[0][0]']
#
#  advanced_quantum_layer_1 (Adva  (None, 128)         65664       ['dropout_1[0][0]']
#  ncedQuantumLayer)
#
#  dropout (Dropout)              (None, 100, 128)     0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 6400)         825600      ['advanced_quantum_layer_1[0][0]'
#                                                                  ]
#
#  reshape_2 (Reshape)            (None, 10, 10, 128)  0           ['dropout[0][0]']
#
#  reshape_3 (Reshape)            (None, 10, 10, 64)   0           ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 10, 10, 192)  0           ['reshape_2[0][0]',
#                                                                   'reshape_3[0][0]']
#
#  spatial_attention (SpatialAtte  (None, 10, 10, 192)  193        ['concatenate[0][0]']
#  ntion)
#
#  conv2d_2 (Conv2D)              (None, 10, 10, 128)  221312      ['spatial_attention[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 10, 10, 128)  512        ['conv2d_2[0][0]']
#  rmalization)
#
#  conv2d_3 (Conv2D)              (None, 10, 10, 64)   73792       ['batch_normalization_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10, 10, 64)   0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 10, 10, 32)   18464       ['dropout_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 10, 10, 16)   4624        ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 10, 10, 1)    145         ['conv2d_5[0][0]']
#
# ==================================================================================================
# Total params: 1,365,954
# Trainable params: 1,365,650
# Non-trainable params: 304
# __________________________________________________________________________________________________
#
# Training details:
#   Samples: 994 training, 213 validation
#   Input shape: (5, 10, 10, 24)
#   Target shape: (10, 10, 1)
#   Model type: Advanced Quantum-Enhanced with Attention
#   Epochs: 100, Batch size: 4
#   Features: Temporal Attention, Spatial Attention, Quantum Entanglement
#   Target parameter: AOD (Aerosol Optical Depth, band index 6)
#
# Starting training...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Layer TemporalAttention has arguments ['units']
# in `__init__` and therefore must override `get_config()`.
#
# Example:
#
# class CustomLayer(keras.layers.Layer):
#     def __init__(self, arg1, arg2):
#         super().__init__()
#         self.arg1 = arg1
#         self.arg2 = arg2
#
#     def get_config(self):
#         config = super().get_config()
#         config.update({
#             "arg1": self.arg1,
#             "arg2": self.arg2,
#         })
#         return config
# Epoch 1/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0474 - mae: 0.1585 - mse: 0.0474
# Epoch 1: val_loss improved from inf to 0.04081, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# 249/249 [==============================] - 35s 104ms/step - loss: 0.0474 - mae: 0.1585 - mse: 0.0474 - val_loss: 0.0408 - val_mae: 0.1526 - val_mse: 0.0408 - lr: 0.0010
# Epoch 2/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0308 - mae: 0.1306 - mse: 0.0308
# Epoch 2: val_loss improved from 0.04081 to 0.03532, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# 249/249 [==============================] - 32s 128ms/step - loss: 0.0308 - mae: 0.1307 - mse: 0.0308 - val_loss: 0.0353 - val_mae: 0.1349 - val_mse: 0.0353 - lr: 0.0010
# Epoch 3/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0286 - mae: 0.1256 - mse: 0.0286
# Epoch 3: val_loss improved from 0.03532 to 0.03248, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# 249/249 [==============================] - 25s 101ms/step - loss: 0.0286 - mae: 0.1256 - mse: 0.0286 - val_loss: 0.0325 - val_mae: 0.1403 - val_mse: 0.0325 - lr: 0.0010
# Epoch 4/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0269 - mae: 0.1225 - mse: 0.0269
# Epoch 4: val_loss improved from 0.03248 to 0.02077, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# 249/249 [==============================] - 27s 107ms/step - loss: 0.0269 - mae: 0.1226 - mse: 0.0269 - val_loss: 0.0208 - val_mae: 0.1059 - val_mse: 0.0208 - lr: 0.0010
# Epoch 5/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0268 - mae: 0.1215 - mse: 0.0268
# Epoch 5: val_loss improved from 0.02077 to 0.01597, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# 249/249 [==============================] - 20s 82ms/step - loss: 0.0267 - mae: 0.1215 - mse: 0.0267 - val_loss: 0.0160 - val_mae: 0.0921 - val_mse: 0.0160 - lr: 0.0010
# Epoch 6/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0263 - mae: 0.1202 - mse: 0.0263
# Epoch 6: val_loss did not improve from 0.01597
# 249/249 [==============================] - 11s 46ms/step - loss: 0.0265 - mae: 0.1206 - mse: 0.0265 - val_loss: 0.0181 - val_mae: 0.0913 - val_mse: 0.0181 - lr: 0.0010
# Epoch 7/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0226 - mae: 0.1109 - mse: 0.0226
# Epoch 7: val_loss improved from 0.01597 to 0.01591, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# 249/249 [==============================] - 25s 99ms/step - loss: 0.0226 - mae: 0.1109 - mse: 0.0226 - val_loss: 0.0159 - val_mae: 0.0953 - val_mse: 0.0159 - lr: 0.0010
# Epoch 8/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0237 - mae: 0.1134 - mse: 0.0237
# Epoch 8: val_loss improved from 0.01591 to 0.01116, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# 249/249 [==============================] - 26s 105ms/step - loss: 0.0237 - mae: 0.1134 - mse: 0.0237 - val_loss: 0.0112 - val_mae: 0.0771 - val_mse: 0.0112 - lr: 0.0010
# Epoch 9/100
# 247/249 [============================>.] - ETA: 0s - loss: 0.0214 - mae: 0.1089 - mse: 0.0214
# Epoch 9: val_loss did not improve from 0.01116
# 249/249 [==============================] - 9s 34ms/step - loss: 0.0213 - mae: 0.1088 - mse: 0.0213 - val_loss: 0.0154 - val_mae: 0.0869 - val_mse: 0.0154 - lr: 0.0010
# Epoch 10/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0189 - mae: 0.1008 - mse: 0.0189
# Epoch 10: val_loss improved from 0.01116 to 0.00684, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# 249/249 [==============================] - 29s 115ms/step - loss: 0.0189 - mae: 0.1008 - mse: 0.0189 - val_loss: 0.0068 - val_mae: 0.0595 - val_mse: 0.0068 - lr: 0.0010
# Epoch 11/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0173 - mae: 0.0992 - mse: 0.0173
# Epoch 11: val_loss did not improve from 0.00684
# 249/249 [==============================] - 15s 61ms/step - loss: 0.0174 - mae: 0.0995 - mse: 0.0174 - val_loss: 0.0159 - val_mae: 0.0792 - val_mse: 0.0159 - lr: 0.0010
# Epoch 12/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0184 - mae: 0.1009 - mse: 0.0184
# Epoch 12: val_loss improved from 0.00684 to 0.00611, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# 249/249 [==============================] - 34s 138ms/step - loss: 0.0184 - mae: 0.1009 - mse: 0.0184 - val_loss: 0.0061 - val_mae: 0.0536 - val_mse: 0.0061 - lr: 0.0010
# Epoch 13/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0176 - mae: 0.0989 - mse: 0.0176
# Epoch 13: val_loss did not improve from 0.00611
# 249/249 [==============================] - 16s 66ms/step - loss: 0.0176 - mae: 0.0989 - mse: 0.0176 - val_loss: 0.1887 - val_mae: 0.2874 - val_mse: 0.1887 - lr: 0.0010
# Epoch 14/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0163 - mae: 0.0946 - mse: 0.0163
# Epoch 14: val_loss did not improve from 0.00611
# 249/249 [==============================] - 16s 66ms/step - loss: 0.0163 - mae: 0.0946 - mse: 0.0163 - val_loss: 0.0103 - val_mae: 0.0702 - val_mse: 0.0103 - lr: 0.0010
# Epoch 15/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0162 - mae: 0.0957 - mse: 0.0162
# Epoch 15: val_loss did not improve from 0.00611
# 249/249 [==============================] - 18s 73ms/step - loss: 0.0162 - mae: 0.0957 - mse: 0.0162 - val_loss: 0.0271 - val_mae: 0.0938 - val_mse: 0.0271 - lr: 0.0010
# Epoch 16/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0160 - mae: 0.0940 - mse: 0.0160
# Epoch 16: val_loss did not improve from 0.00611
# 249/249 [==============================] - 18s 72ms/step - loss: 0.0160 - mae: 0.0940 - mse: 0.0160 - val_loss: 0.0112 - val_mae: 0.0721 - val_mse: 0.0112 - lr: 0.0010
# Epoch 17/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0156 - mae: 0.0912 - mse: 0.0156
# Epoch 17: val_loss did not improve from 0.00611
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 249/249 [==============================] - 11s 44ms/step - loss: 0.0156 - mae: 0.0912 - mse: 0.0156 - val_loss: 0.0091 - val_mae: 0.0669 - val_mse: 0.0091 - lr: 0.0010
# Epoch 18/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0132 - mae: 0.0871 - mse: 0.0132
# Epoch 18: val_loss did not improve from 0.00611
# 249/249 [==============================] - 11s 45ms/step - loss: 0.0132 - mae: 0.0871 - mse: 0.0132 - val_loss: 0.0065 - val_mae: 0.0556 - val_mse: 0.0065 - lr: 5.0000e-04
# Epoch 19/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0128 - mae: 0.0836 - mse: 0.0128
# Epoch 19: val_loss improved from 0.00611 to 0.00451, saving model to C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_best_model\assets
# 249/249 [==============================] - 17s 68ms/step - loss: 0.0128 - mae: 0.0836 - mse: 0.0128 - val_loss: 0.0045 - val_mae: 0.0487 - val_mse: 0.0045 - lr: 5.0000e-04
# Epoch 20/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0136 - mae: 0.0876 - mse: 0.0136
# Epoch 20: val_loss did not improve from 0.00451
# 249/249 [==============================] - 11s 43ms/step - loss: 0.0136 - mae: 0.0876 - mse: 0.0136 - val_loss: 0.0168 - val_mae: 0.0787 - val_mse: 0.0168 - lr: 5.0000e-04
# Epoch 21/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0138 - mae: 0.0886 - mse: 0.0138
# Epoch 21: val_loss did not improve from 0.00451
# 249/249 [==============================] - 11s 44ms/step - loss: 0.0138 - mae: 0.0886 - mse: 0.0138 - val_loss: 0.0358 - val_mae: 0.1023 - val_mse: 0.0358 - lr: 5.0000e-04
# Epoch 22/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0140 - mae: 0.0888 - mse: 0.0140
# Epoch 22: val_loss did not improve from 0.00451
# 249/249 [==============================] - 11s 42ms/step - loss: 0.0140 - mae: 0.0888 - mse: 0.0140 - val_loss: 0.0148 - val_mae: 0.0735 - val_mse: 0.0148 - lr: 5.0000e-04
# Epoch 23/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0120 - mae: 0.0834 - mse: 0.0120
# Epoch 23: val_loss did not improve from 0.00451
# 249/249 [==============================] - 11s 45ms/step - loss: 0.0120 - mae: 0.0833 - mse: 0.0120 - val_loss: 0.0096 - val_mae: 0.0706 - val_mse: 0.0096 - lr: 5.0000e-04
# Epoch 24/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0135 - mae: 0.0861 - mse: 0.0135
# Epoch 24: val_loss did not improve from 0.00451
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 249/249 [==============================] - 11s 44ms/step - loss: 0.0135 - mae: 0.0861 - mse: 0.0135 - val_loss: 0.0127 - val_mae: 0.0728 - val_mse: 0.0127 - lr: 5.0000e-04
# Epoch 25/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0127 - mae: 0.0847 - mse: 0.0127
# Epoch 25: val_loss did not improve from 0.00451
# 249/249 [==============================] - 11s 45ms/step - loss: 0.0127 - mae: 0.0847 - mse: 0.0127 - val_loss: 0.0142 - val_mae: 0.0716 - val_mse: 0.0142 - lr: 2.5000e-04
# Epoch 26/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0136 - mae: 0.0880 - mse: 0.0136
# Epoch 26: val_loss did not improve from 0.00451
# 249/249 [==============================] - 11s 46ms/step - loss: 0.0136 - mae: 0.0880 - mse: 0.0136 - val_loss: 0.0132 - val_mae: 0.0732 - val_mse: 0.0132 - lr: 2.5000e-04
# Epoch 27/100
# 248/249 [============================>.] - ETA: 0s - loss: 0.0111 - mae: 0.0797 - mse: 0.0111
# Epoch 27: val_loss did not improve from 0.00451
# 249/249 [==============================] - 11s 45ms/step - loss: 0.0111 - mae: 0.0797 - mse: 0.0111 - val_loss: 0.0186 - val_mae: 0.0807 - val_mse: 0.0186 - lr: 2.5000e-04
# Epoch 28/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0113 - mae: 0.0788 - mse: 0.0113
# Epoch 28: val_loss did not improve from 0.00451
# 249/249 [==============================] - 11s 45ms/step - loss: 0.0113 - mae: 0.0788 - mse: 0.0113 - val_loss: 0.0082 - val_mae: 0.0628 - val_mse: 0.0082 - lr: 2.5000e-04
# Epoch 29/100
# 249/249 [==============================] - ETA: 0s - loss: 0.0132 - mae: 0.0846 - mse: 0.0132
# Epoch 29: val_loss did not improve from 0.00451
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Restoring model weights from the end of the best epoch: 19.
# 249/249 [==============================] - 10s 41ms/step - loss: 0.0132 - mae: 0.0846 - mse: 0.0132 - val_loss: 0.0088 - val_mae: 0.0642 - val_mse: 0.0088 - lr: 2.5000e-04
# Epoch 29: early stopping
#
# Training completed in 508.05 seconds
#
# ============================================================
# EVALUATING EXPERT 14
# ============================================================
# 54/54 [==============================] - 1s 16ms/step
#
# 📊 PERFORMANCE METRICS:
#   MSE:  0.0044
#   MAE:  0.0470
#   R²:   0.8967
#
# 📈 DISTRIBUTION ANALYSIS:
#   True - Min: 0.00, Max: 0.99, Mean: 0.45
#   Pred - Min: -0.02, Max: 1.21, Mean: 0.44
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_final_model\assets
# INFO:tensorflow:Assets written to: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output\expert14_final_model\assets
# 💾 Expert 14 saved successfully!
#    Model: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output/expert14_final_model/ (TensorFlow format)
#    Weights: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output/expert14_weights.h5
#    Metadata: C:\Users\NNadi\Downloads\Air_pollution_Agentic_AI\models\expert14_output/expert14_metadata.json
#
# ✅ EXPERT 14 COMPLETED SUCCESSFULLY!
# 📁 Model ready for ensemble stacking!
#
# 🧪 Testing model loading...
# ✅ Model loaded successfully for ensemble integration!
